# %%
import pandas as pd
import numpy as np
import os.path as osp
from collections import defaultdict
from scipy.optimize import curve_fit
from scipy.stats import norm,ranksums,ttest_ind,ttest_ind_from_stats
from sklearn.metrics import roc_curve,auc
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.colors import LogNorm,CenteredNorm
from matplotlib_venn import venn2,venn3
plt.rcParams['svg.fonttype']='none'
from itertools import combinations as combs
INPUT_DIR = '../../data/Experimental_Results'
OUTPUT_DIR = '../../output/Experimental_Results'

# %%
cmp_info = pd.read_table(osp.join(INPUT_DIR,'compoundinfo_beta.txt.gz'))
nuid_drg_info = pd.read_excel(osp.join(INPUT_DIR,'combined_drug_information.xlsx'),
                              engine='openpyxl',sheet_name='NU-HTA Drug Metadata')
supp_drg_info = pd.read_excel(osp.join(INPUT_DIR,'combined_drug_information.xlsx'),
                              engine='openpyxl',sheet_name='MedChemExpress Drug Metadata')
casmap = pd.read_excel(osp.join(INPUT_DIR,'updated_casmapping_050422_data.xlsx'),
                       engine='openpyxl',index_col=0)

## determine which drugs are annotated for cancer
L1 = [elt.lower() for elt in casmap.LINCS_NAME.values]
L2 = [elt for elt in casmap.CAS.values]
name2CAS = pd.Series(dict(zip(L1,L2)))  ## name2CAS
L3 = [elt.lower() for elt in casmap.BRD.values] 
BRD2CAS = pd.Series(dict(zip(L3,L2))) ## BRD2CAS


cmap_nms = cmp_info.cmap_name.unique()
lwr_upper_d = dict([(cmn.lower(),cmn) for cmn in cmap_nms])
cmap_nms_lwr = [cmn.lower() for cmn in cmap_nms]

diffs = {'acetaminophen', 'bgj398', 'bix01294', 
         'cgp-60474', 'encorafenib', 'gsk-1059615', 
         'gsk-126', 'gsk1120212', 'ikk-16', 'jq1', 
         'jtc-801', 'ldn-193189', 'm-344', 'mc 1568', 
         'mycophenolic acid', 'osi-027', 'pik-75', 
         'retinoic acid', 'sgc-cbp30', 'torin 2', 'zm447439'}

## convert the predictions into a number of value counts
comb_pred_list = pd.read_pickle(osp.join(INPUT_DIR,'comb_pred_list_210522.pkl'))
c1vcs = comb_pred_list.index.get_level_values(0).value_counts()
c2vcs = comb_pred_list.index.get_level_values(1).value_counts()
cvcs = pd.concat([c1vcs,c2vcs],axis=1).sum(axis=1)

charac = cmp_info[cmp_info.pert_id.isin(casmap.BRD.unique())|
                  cmp_info.cmap_name.isin(casmap.LINCS_NAME.unique())].pert_id.unique()
nonlincs_nuid_table = pd.read_excel(osp.join(INPUT_DIR,'non_lincs_drugs_casmapping.xlsx'),
                                    engine='openpyxl',index_col=0)
nonlincs_nuid_table.index = [elt.lower() for elt in nonlincs_nuid_table.index]

man_map ={'5-fluorouracil':'fluorouracil', 'gnf2---lincs':'gnf-2','mpa':'medroxyprogesterone-acetate',
 'jib04':'jib-04','cmap-erg-azd2281---lincs':'cmap-erg-azd2281','omiplasib':'gsk-2126458','razoxane':'dexrazoxane',
'tetryzoline':'tetrahydrozoline','i-bet-762':'gsk-525762a'}

## construct a mapping between the names and the cas numbers
nm_cas = {}
for elt in cvcs.index:
    if elt in name2CAS.index:
        nm_cas[elt]=name2CAS[elt]
    elif elt in BRD2CAS.index:
        nm_cas[elt]=BRD2CAS[elt]
    elif elt in nonlincs_nuid_table.index:
        if elt != 'bleomycin':
            nm_cas[elt]=nonlincs_nuid_table.CAS_no.loc[elt]
    else:
        if elt in man_map.keys():
            nm_cas[elt]=name2CAS[man_map[elt]]
        elif elt=='chlortalidone':
            nm_cas[elt]='77-36-1'
nm_cas['bleomycin']='9041-93-4'
nm_cas_ser = pd.Series(nm_cas)
## this variable sets the overlap between the med chem express drug information
## and the cas numbers
OVR = set(nm_cas_ser.values) & set(supp_drg_info['CAS Number'].values)

XX = cmp_info[cmp_info.pert_id.isin(charac)]
diff = set(XX.pert_id.unique())-set(XX[XX.cmap_name.isin(casmap.LINCS_NAME.values)].pert_id.unique())
YY = cmp_info[cmp_info.pert_id.isin(diff)]

## identify the cancer drugs by either identifier
match_df_l = []
for elt in diff:
    lincsnm = YY[YY.pert_id==elt].compound_aliases.iloc[0]
    casn = casmap[casmap.LINCS_NAME==lincsnm].CAS.unique()
    SEL = supp_drg_info[[elt2 in set(casn) for elt2 in supp_drg_info['CAS Number'].values]]
    ra_l = []
    pw_l = []
    if len(SEL)>0:
        for elt3 in SEL['Research Area'].values:
            ra_l.extend(elt3.split('; '))
        for elt4 in SEL['Pathway'].values:
            pw_l.extend(elt4.split('; '))
            
    match_df_l.append({'BRD':elt,'CAS':casn,'LINCS_NAME':lincsnm.lower(),'RA':ra_l,'PW':pw_l})

for elt in XX[XX.cmap_name.isin(casmap.LINCS_NAME.values)].pert_id.unique():
    lincsnm = XX[XX.pert_id==elt].cmap_name.iloc[0]
    casn = casmap[casmap.LINCS_NAME==lincsnm].CAS.unique()
    SEL = supp_drg_info[[elt2 in set(casn) for elt2 in supp_drg_info['CAS Number'].values]]
    ra_l = []
    pw_l = []
    if len(SEL)>0:
        for elt3 in SEL['Research Area'].values:
            ra_l.extend(elt3.split('; '))
        for elt4 in SEL['Pathway'].values:
            pw_l.extend(elt4.split('; '))
    match_df_l.append({'BRD':elt,'CAS':casn,'LINCS_NAME':lincsnm.lower(),'RA':ra_l,'PW':pw_l})
match_df = pd.DataFrame(match_df_l)

## break down the unselected drugs into cancer matching and noncancer matching
canc_match_df = match_df[['Cancer' in ll for ll in match_df.RA.values]]
canc_nonmatch_df = match_df[['Cancer' not in ll and len(ll)>0 for ll in match_df.RA.values]]
nora_df = match_df[[len(ll)==0 for ll in match_df.RA.values]]
unsel_canc_match = canc_match_df[~canc_match_df.LINCS_NAME.isin(nm_cas_ser.index)]
unsel_canc_match = unsel_canc_match[~unsel_canc_match.LINCS_NAME.duplicated()]
unsel_noncanc_match = canc_nonmatch_df[~canc_nonmatch_df.LINCS_NAME.isin(nm_cas_ser.index)]
unsel_noncanc_match = unsel_noncanc_match[~unsel_noncanc_match.LINCS_NAME.duplicated()]
unsel_no_match = nora_df[~nora_df.LINCS_NAME.isin(nm_cas_ser.index)]
unsel_no_match = unsel_no_match[~unsel_no_match.LINCS_NAME.duplicated()]

np.random.seed(987654321) ## set seed for reproducibility
rnd_canc_sel = np.random.permutation(np.arange(unsel_canc_match.shape[0])) ## select 8 from unselected, cancer-annotated group
rnd_noncanc_sel = np.random.permutation(np.arange(unsel_noncanc_match.shape[0])) ## select 4 from unselected, other-annotated group
rnd_nomatch_sel = np.random.permutation(np.arange(unsel_no_match.shape[0])) ## select 4 from unselected, unannotated group
Ncanc = 7
Nnoncanc=3
Nnomatch=3

DF = unsel_canc_match[~unsel_canc_match.LINCS_NAME.duplicated()].iloc[rnd_canc_sel]
row_l = []
pw_ovr_l = []
pw_count = defaultdict(int)
for dum,row in DF.iterrows():
    if len(row_l)>Ncanc:
        break
    casn = row.loc['CAS']
    pw_l = row.loc['PW']
    if len(set(pw_l)&set(pw_ovr_l))<1:
        row_l.append(row)
        pw_ovr_l.extend(pw_l)
        for pw in pw_l:
            pw_count[pw]+=1
    else:
        if all([pw_count[pw]<2 for pw in pw_l]):
            row_l.append(row)
            pw_ovr_l.extend(pw_l)
            for pw in pw_l:
                pw_count[pw]+=1
        
rs1 =  pd.DataFrame(row_l)

DF2 = unsel_noncanc_match[~unsel_noncanc_match.LINCS_NAME.duplicated()].iloc[rnd_noncanc_sel]
row_l2 = []
pw_ovr_l2 = []
for dum,row in DF2.iterrows():
    if len(row_l2)>Nnoncanc:
        break
    casn = row.loc['CAS']
    pw_l = row.loc['PW']
    if len(set(pw_l)&set(pw_ovr_l2))<1:
        row_l2.append(row)
        pw_ovr_l2.extend(pw_l)
rs2 = pd.DataFrame(row_l2)

DF3 = unsel_no_match[~unsel_no_match.LINCS_NAME.duplicated()].iloc[rnd_nomatch_sel]
row_l3 = []
pw_ovr_l3 = []
for dum,row in DF3.iterrows():
    if len(row_l3)>Nnomatch:
        break
    casn = row.loc['CAS']
    pw_l = row.loc['PW']
    if len(set(pw_l)&set(pw_ovr_l3))<1:
        row_l3.append(row)
        pw_ovr_l3.extend(pw_l)
rs3 = pd.DataFrame(row_l3)
rand_all2all = pd.DataFrame(row_l+row_l2+row_l3)

rem = [
 ('brd-a11605036', '602-41-5'),
 ('ginkgetin', '481-46-9'),
 ('ivermectin', '70288-86-7'), 
 ('brd-k51073125', '50-53-3'),
 ('trehalose', '99-20-7'),
 ('antimycin-a', '1397-94-0'),
 ('thiostrepton','1393-48-2'),
 ('oxolinic-acid','14698-29-4')]
rem_nms, rem_cas = zip(*rem)
remA=~comb_pred_list.index.get_level_values(0).isin(rem_nms)
remB=~comb_pred_list.index.get_level_values(1).isin(rem_nms)
comb_pred_list = comb_pred_list[remA&remB]
rsums = comb_pred_list.sum(axis=1).sort_values(ascending=False)
srt_inds = rsums.index

# %% [markdown]
# ### Load viability data and metadata

# %% [markdown]
# `reduced_dosage_d`: a Python dictionary with keys corresponding to drugs and values indicating the number of nanoliters added to the plate. 40nL = 10uM.

# %%
reduced_dosage_d = {'doxorubicin':2.5,'torin 2':2.5,'gsk1120212':20,
'mycophenolic acid':20,'ciclopirox':20,'daunorubicin':2.5,
'digoxin':2.5,'digitoxin':2.5,'topotecan':2.5,
'melphalan':20,'zm447439':20,'anisomycin':20,
'sgc-cbp30':20,'calcipotriol':20,'lomefloxacin':20}

# %% [markdown]
# `sel_df_comb`: a pandas DataFrame containing the viability data from each well for each cell line, plate, and replicate.
#
# Rows are labeled by plate wells and columns are labeled by a tuple of (`Cell_Line`, `Plate_Layout`, `Replicate`).
#
# Cell Line can be one of `CH`:CH-157MN, `IO`:IOMM-LEE, `43`:GBM43, or `LN`:LN-229.
#
# Plate Layout can be `A`:alpha or `B`:beta, specifying the layout detailed in Supplementary data file S6.
#
# The viability data in this repository corresponds to that reported in Supplementary data file S7.
#
# Statistics calculated in this notebook correspond to those reported in Supplementary data file S8.

# %%
sel_df_comb = pd.read_csv(osp.join(INPUT_DIR,'viability_data.csv'),index_col=0,header=[0,1,2])

# %% [markdown]
# `drug2moa`: a Python dictionary with keys corresponding to drug names and values corresponding to mechanism(s) of action.

# %%
def read_drug2moa(fn):
    drug2moa = {}
    with open(fn,'r') as fh:
        for ln in fh:
            if ln.startswith('##'):
                continue
            k,vv = ln.split('\t')
            if ',' in vv:
                drug2moa[k]=vv.rstrip().split(',')
            else:
                drug2moa[k]=vv.rstrip()
    return drug2moa
drug2moa =read_drug2moa(osp.join(INPUT_DIR,'drug2moa.txt'))

# %% [markdown]
# `test_grps`: pandas DataFrame that contains the plate layout for the experiment, including the drug group and prediction rank
#
# `transfer_file`: spreadsheet file used to operate the Echo robot that dispenses the drugs. It includes a mapping of drugs names to CAS numbers and NU-HTAL ids in addition to mapping the wells.
#
# `alpha_plate`: drugs that appear on the "alpha" plate layout
#
# `beta_plate`: drugs that appear on the "beta" plate layout

# %%
test_grps = pd.read_excel(osp.join(INPUT_DIR,'DatasetS4_plate_schematic.xlsx'),sheet_name='Drug Groupings',engine='openpyxl',index_col=[0,1])
transfer_file = pd.read_excel(osp.join(INPUT_DIR,'transfer_file.xlsx'),engine='openpyxl',index_col=0,header=0)
alpha_plate = transfer_file[transfer_file['Destination Plate']=='IOMM-LEE_alpha_1']
beta_plate = transfer_file[transfer_file['Destination Plate']=='IOMM-LEE_beta_1']

GB_alpha = alpha_plate.groupby('Destination Well')
GB_beta = beta_plate.groupby('Destination Well')

# %% [markdown]
# `index_dict`: dictionary mapping different groups to top selected drugs (the top overall selected drugs as well as those that are specific to given methods)
#
# The following are dictionaries mapping drug pairs of specified categories to their wells & total volume of the drugs.
# 1. `sel_inds_d`:  top selected drug pairs
# 2. `sel_inds_singles`: single-drug treatments of the top selected drugs
# 3. `noncanc_alpha_d`: non-cancer drugs and drug pairs that are on the 'alpha' layout plate
# 4. `noncanc_beta_d`:  non-cancer drugs and drug pairs that are on the 'beta' layout plate
# 5. `ld_inds_d`: low-dosage drugs and drug pairs
# 6. `antisel_well_d`: anti-selected drug pairs
# 7. `nonsel_inds_d`: randomly-selected drug pairs

# %%
## this should have the drug-name-to-well mapping that is needed above
index_dict = pd.read_pickle(osp.join(INPUT_DIR,'index_dict.pkl'))
sel_inds_d = pd.read_pickle(osp.join(INPUT_DIR,'sel_inds_d.pkl'))
sel_inds_singles = pd.read_pickle(osp.join(INPUT_DIR,'sel_inds_singles.pkl'))
noncanc_alpha_d = pd.read_pickle(osp.join(INPUT_DIR,'noncanc_alpha_d.pkl'))
noncanc_beta_d = pd.read_pickle(osp.join(INPUT_DIR,'noncanc_beta_d.pkl'))
ld_inds_d2 = pd.read_pickle(osp.join(INPUT_DIR,'ld_inds_d.pkl'))
ld_inds_d = {}
for k,v in ld_inds_d2.items():
    if isinstance(k,tuple):
        ld_inds_d[tuple(list(sorted(k)))]=v
    else:
        ld_inds_d[k]=v
antisel_well_d = pd.read_pickle(osp.join(INPUT_DIR,'antisel_well_d.pkl'))
nonsel_inds_d2 = pd.read_pickle(osp.join(INPUT_DIR,'nonsel_inds_d.pkl'))
nonsel_inds_d = {}
for k,v in nonsel_inds_d2.items():
    if isinstance(k,tuple):
        nonsel_inds_d[tuple(list(sorted(k)))]=v
    else:
        nonsel_inds_d[k]=v

# %%
## nonadditive/additive drug pair analysis

nadd_sums = comb_pred_list.loc[:,('nonadditive','0.79')]
nadd_inds = nadd_sums[~nadd_sums.isna()].index

add_sums = comb_pred_list.loc[:,('additive','0.79')]
add_inds = add_sums[~add_sums.isna()].index

nadd_only_inds = nadd_inds.difference(add_inds)
add_only_inds = add_inds.difference(nadd_inds)
nadd_add_isect = nadd_inds.intersection(add_inds)
alt_term_predictions = (comb_pred_list.index.difference(nadd_inds.union(add_inds)))
print('Nonadditive only (pairs):',nadd_only_inds.shape[0])
print('Additive only (pairs):',add_only_inds.shape[0])
print('Intersection (pairs):',nadd_add_isect.shape[0])
print('Single-term predictions (pairs):',alt_term_predictions.shape[0])
# Out:
# Nonadditive only (pairs): 6638
# Additive only (pairs): 8515
# Intersection (pairs): 6261
# Single-term predictions (pairs): 6814

# %%
## nonadditive/additive single drug analysis
nadd_vcs1=nadd_sums[nadd_sums>0].index.get_level_values(0).value_counts()
nadd_vcs2=nadd_sums[nadd_sums>0].index.get_level_values(1).value_counts()
add_vcs1=add_sums[add_sums>0].index.get_level_values(0).value_counts()
add_vcs2=add_sums[add_sums>0].index.get_level_values(1).value_counts()
all_vcs1 = comb_pred_list.index.get_level_values(0).value_counts()
all_vcs2 = comb_pred_list.index.get_level_values(1).value_counts()

nadd_vcs_single=pd.concat([nadd_vcs1,nadd_vcs2],axis=1).sum(axis=1)
add_vcs_single=pd.concat([add_vcs1,add_vcs2],axis=1).sum(axis=1)
all_vcs_single=pd.concat([all_vcs1,all_vcs2],axis=1).sum(axis=1)

nadd_single_only=nadd_vcs_single.index.difference(add_vcs_single.index)
nadd_add_single_intersection=add_vcs_single.index.intersection(nadd_vcs_single.index)
add_single_only=add_vcs_single.index.difference(nadd_vcs_single.index)
alt_term_predictions_single = all_vcs_single.index.difference(nadd_vcs_single.index.union(add_vcs_single.index))

print('Nonadditive only (single):',nadd_single_only.shape[0])
print('Additive only (single):',add_single_only.shape[0])
print('Intersection (single):',nadd_add_single_intersection.shape[0])
print('Single-term predictions (single):',alt_term_predictions_single.shape[0])
# Out:
# Nonadditive only (single): 163
# Additive only (single): 70
# Intersection (single): 809
# Single-term predictions (single): 70

# %%
## the dictionaries below do, in fact, contain the correct drug names used in the well mapping.
## now can compare with the drugs above...

## comparisons to do:
## 1. index_dict[('all','all','top')] keys and sel_inds_d.keys()
TOP_KW = 'Top selected (brown)'
TOP_KW_ASSAY_MI = pd.MultiIndex.from_tuples([tuple(elt) for elt in test_grps[test_grps.group==TOP_KW].loc[:,['drug1_name','drug2_name']].values])
print('Top consensus (pair) in both add/nonadd:',len(TOP_KW_ASSAY_MI.intersection(nadd_add_isect)))
consensus_vcs1 = TOP_KW_ASSAY_MI.get_level_values(0).value_counts()
consensus_vcs2 = TOP_KW_ASSAY_MI.get_level_values(1).value_counts()
consensus_single = pd.concat([consensus_vcs1,consensus_vcs2],axis=1).sum(axis=1).index
print('Top consensus (single) in both add/nonadd:',consensus_single.shape[0])
print(TOP_KW_ASSAY_MI.shape[0])
# Out:
# Top consensus (pair) in both add/nonadd: 42
# Top consensus (single) in both add/nonadd: 25
# 42

# %%
alt_term_predictions_single = all_vcs_single.index.difference(nadd_vcs_single.index.union(add_vcs_single.index))
print('Both (single):', consensus_single.intersection(nadd_add_single_intersection).shape[0])
single_n1 = consensus_single.intersection(nadd_add_single_intersection).shape[0]
# Out:
# Both (single): 25

# %%
## 2. index_dict[('nonadditive', 'comb', 'top')] keys and sel_inds_d.keys()
NADD_KW = 'Nonadditive average (gray)'
## NADD_KW_INDS = index_dict[NADD_KW]
TOP_NADD_MI = pd.MultiIndex.from_tuples([tuple(elt) for elt in test_grps[test_grps.group==NADD_KW].loc[:,['drug1_name','drug2_name']].values])
print('Top nonadditive (pair) overlap:',len(TOP_NADD_MI.intersection(nadd_only_inds)))
print(TOP_NADD_MI.shape[0])
nonadditive_vcs1 = TOP_NADD_MI.get_level_values(0).value_counts()
nonadditive_vcs2 = TOP_NADD_MI.get_level_values(1).value_counts()
nonadditive_single = pd.concat([nonadditive_vcs1,nonadditive_vcs2],axis=1).sum(axis=1).index
print('Top nonadditive (single) overlap:', nonadditive_single.intersection(nadd_add_single_intersection).shape[0])
print(nonadditive_single.shape[0])
# Out:
# Top nonadditive (pair) overlap: 14
# 15
# Top nonadditive (single) overlap: 24
# 24

# %%
S1A = [tuple(elt) for elt in test_grps[test_grps.group=='Nonadditive average (gray)'].loc[:,['drug1_name','drug2_name']].values]
S2B = [tuple(elt) for elt in index_dict[('nonadditive', 'comb', 'top')]]
S1C = [tuple(elt) for elt in test_grps[test_grps.group=='Additive average (gray)'].loc[:,['drug1_name','drug2_name']].values]
S2D = [tuple(elt) for elt in index_dict[('additive', 'comb', 'top')]]
S1E = [tuple(elt) for elt in test_grps[test_grps.group=='Non-growth average (red)'].loc[:,['drug1_name','drug2_name']].values]
S2F = [tuple(elt) for elt in index_dict[('comb', '1.57', 'bot')]]
S1G = [tuple(elt) for elt in test_grps[test_grps.group=='Combined average (orange)'].loc[:,['drug1_name','drug2_name']].values]
S2H = [tuple(elt) for elt in index_dict[('comb', '0.79', 'top')]]
S1I = [tuple(elt) for elt in test_grps[test_grps.group=='Combined nonadditive (orange)'].loc[:,['drug1_name','drug2_name']].values]
S2J = [tuple(elt) for elt in index_dict[('nonadditive', '0.79', 'top')]]
S1K = [tuple(elt) for elt in test_grps[test_grps.group=='Combined additive (orange)'].loc[:,['drug1_name','drug2_name']].values]
S2L = [tuple(elt) for elt in index_dict[('additive', '0.79', 'top')]]
len((set(S1A) & set(S2B))|(set(S1C) & set(S2D))|(set(S1E) & set(S2F))|(set(S1G) & set(S2H))|(set(S1I) & set(S2J))|(set(S1K) & set(S2L)))
## there are 2 extra pairs (fenbendazole/mycophenolic acid) (m-344 /retinoic acid) for a total of 64
# Out:
# 62

# %%
## 3. index_dict[('additive', 'comb', 'top')] keys and sel_inds_d.keys()

ADD_KW = 'Additive average (gray)'
TOP_ADD_MI = pd.MultiIndex.from_tuples([tuple(elt) for elt in test_grps[test_grps.group==ADD_KW].loc[:,['drug1_name','drug2_name']].values])
print('Top additive (pair) overlap:',len(TOP_ADD_MI.intersection(add_only_inds)))
print(TOP_ADD_MI.shape[0])
additive_vcs1 = TOP_ADD_MI.get_level_values(0).value_counts()
additive_vcs2 = TOP_ADD_MI.get_level_values(1).value_counts()
additive_single = pd.concat([additive_vcs1,additive_vcs2],axis=1).sum(axis=1).index
print('Top additive (single) overlap:', additive_single.intersection(nadd_add_single_intersection).shape[0])
print(additive_single.shape[0])
# Out:
# Top additive (pair) overlap: 21
# 21
# Top additive (single) overlap: 26
# 26

# %%
from functools import reduce
## 4. More method-specific pairs  index_dict[('comb', '0.79', 'top')] keys and sel_inds_d.keys()
MS_KW_L = ['Non-growth average (red)', 'Combined average (orange)', 'Combined nonadditive (orange)', 'Combined additive (orange)']
TOP_MS_MI = pd.MultiIndex.from_tuples([tuple(elt) for elt in test_grps[test_grps.group.isin(MS_KW_L)].loc[:,['drug1_name','drug2_name']].values])
TOP_MS = len(set(TOP_MS_MI.tolist()) & set(sel_inds_d.keys()))


print('Method-specific (pair) overlap:',TOP_MS_MI.intersection(nadd_add_isect).shape[0])
print('Method-specific (pair) overlap (nonadd):',TOP_MS_MI.intersection(nadd_only_inds).shape[0])
print('Method-specific (pair) overlap (add):',TOP_MS_MI.intersection(add_only_inds).shape[0])
print(TOP_MS_MI.shape[0])
methodspec_vcs1 = TOP_MS_MI.get_level_values(0).value_counts()
methodspec_vcs2 = TOP_MS_MI.get_level_values(1).value_counts()
methodspec_single = pd.concat([methodspec_vcs1,methodspec_vcs2],axis=1).sum(axis=1).index
print('Method-specific (single) overlap:',methodspec_single.intersection(nadd_add_single_intersection).shape[0])
print(methodspec_single.shape[0])
print(methodspec_single.difference(consensus_single).shape[0])
single_n2 = (methodspec_single.union(additive_single).union(nonadditive_single)).difference(consensus_single).shape[0]
# Out:
# Method-specific (pair) overlap: 18
# Method-specific (pair) overlap (nonadd): 5
# Method-specific (pair) overlap (add): 5
# 28
# Method-specific (single) overlap: 37
# 37
# 27

# %%
## 6. Unselected


## find the keywords of the unselected that have overlaps
unsel_kws = ['Behavior average (blue)','Growth average (green)',
             'Behavior additive (blue)','Growth additive (green)',
             'Behavior nonadditive (blue)','Growth nonadditive (green)']
TOP_UNSEL_MI = pd.MultiIndex.from_tuples([tuple(elt) for elt in test_grps[test_grps.group.isin(unsel_kws)].loc[:,['drug1_name','drug2_name']].values])
TOP_UNSEL = len(set(TOP_UNSEL_MI.tolist()) & set(sel_inds_d.keys()))

print('Unselected (pair) overlap:',TOP_UNSEL_MI.intersection(nadd_add_isect).shape[0])
print('Unselected (pair) overlap (nonadd):',TOP_UNSEL_MI.intersection(nadd_only_inds).shape[0])
print('Unselected (pair) overlap (add):',TOP_UNSEL_MI.intersection(add_only_inds).shape[0])
print(TOP_UNSEL_MI.shape[0])
unselected_vcs1 = TOP_UNSEL_MI.get_level_values(0).value_counts()
unselected_vcs2 = TOP_UNSEL_MI.get_level_values(1).value_counts()
unselected_single = pd.concat([unselected_vcs1,unselected_vcs2],axis=1).sum(axis=1).index
print('Unselected(single) overlap:',unselected_single.intersection(nadd_add_single_intersection).shape[0])
print(unselected_single.shape[0])
# Out:
# Unselected (pair) overlap: 0
# Unselected (pair) overlap (nonadd): 0
# Unselected (pair) overlap (add): 0
# 36
# Unselected(single) overlap: 46
# 46

# %%
## UNSEL_INDS=UNSEL_INDS.tolist()
## del UNSEL_INDS[UNSEL_INDS.index(('hydrocortisone', 'rifapentine'))]
## UNSEL_INDS.append(('cortisol', 'rifapentine'))
## del UNSEL_INDS[UNSEL_INDS.index(('brd-k63750851', 'fenbendazole'))]
## UNSEL_INDS.append(('mycophenolic acid', 'fenbendazole'))
## del UNSEL_INDS[UNSEL_INDS.index(('brd-k63750851', 'tolbutamide'))] ## this is actually included in the overall predictions
print('Both (unselected):', unselected_single.intersection(nadd_add_single_intersection).shape[0])
single_n61 = unselected_single.intersection(nadd_add_single_intersection).shape[0]
## test_grps[(test_grps.drug2_name.isna())&(test_grps.group!='Low-dosage')] ## 157 unique drugs
# Out:
# Both (unselected): 46

# %%
## find the keywords of the unselected that have overlaps
unsel_kws = ['Behavior average (blue)','Growth average (green)',
             'Behavior additive (blue)','Growth additive (green)',
             'Behavior nonadditive (blue)','Growth nonadditive (green)']
TOP_UNSEL_MI = pd.MultiIndex.from_tuples([tuple(elt) for elt in test_grps[test_grps.group.isin(unsel_kws)].loc[:,['drug1_name','drug2_name']].values])
TOP_UNSEL = len(set(TOP_UNSEL_MI.tolist()) & set(sel_inds_d.keys()))

print('Unselected (pair) overlap:',TOP_UNSEL_MI.intersection(nadd_add_isect).shape[0])
print('Unselected (pair) overlap (nonadd):',TOP_UNSEL_MI.intersection(nadd_only_inds).shape[0])
print('Unselected (pair) overlap (add):',TOP_UNSEL_MI.intersection(add_only_inds).shape[0])
print(TOP_UNSEL_MI.shape[0])
unselected_vcs1 = TOP_UNSEL_MI.get_level_values(0).value_counts()
unselected_vcs2 = TOP_UNSEL_MI.get_level_values(1).value_counts()
unselected_single = pd.concat([unselected_vcs1,unselected_vcs2],axis=1).sum(axis=1).index
print('Unselected(single) overlap:',unselected_single.intersection(nadd_add_single_intersection).shape[0])
print(unselected_single.shape[0])
# Out:
# Unselected (pair) overlap: 0
# Unselected (pair) overlap (nonadd): 0
# Unselected (pair) overlap (add): 0
# 36
# Unselected(single) overlap: 46
# 46

# %%
## 7. Noncancer pairs
ncpairs_MI = pd.MultiIndex.from_tuples([kw for kw in noncanc_alpha_d.keys() if isinstance(kw,tuple)])
len(nadd_add_isect.intersection(ncpairs_MI))
# Out:
# 38

# %%
ncsingle_a = [kw for kw in noncanc_alpha_d.keys() if isinstance(kw,str)]
ncsingle_b = [kw for kw in noncanc_beta_d.keys() if isinstance(kw,str)]
ncsingle = set(ncsingle_a+ncsingle_b)
print('Both (noncancer):',len(set(ncsingle)&set(nadd_add_single_intersection.tolist())))
single_n3 = len(set(ncsingle)&set(nadd_add_single_intersection.tolist()))
# Out:
# Both (noncancer): 14

# %%
## 8. Anti-selected pairs
antisel_MI = pd.MultiIndex.from_tuples([elt for elt in test_grps[test_grps.group=='Anti-selected'].loc[:,['drug1_name','drug2_name']].values if not isinstance(elt[1],float)])
#antisel_MI.intersection(ncsingle2_MI)
print('Anti-selected (pair) overlap:',len(nadd_add_isect.intersection(antisel_MI)))
print('Anti-selected (pair) overlap (nadd):',len(nadd_only_inds.intersection(antisel_MI)))
print('Anti-selected (pair) overlap (add):',len(add_only_inds.intersection(antisel_MI)))
print('Anti-selected (pair) overlap (other):',len(alt_term_predictions.intersection(antisel_MI)))
# Out:
# Anti-selected (pair) overlap: 1
# Anti-selected (pair) overlap (nadd): 4
# Anti-selected (pair) overlap (add): 13
# Anti-selected (pair) overlap (other): 18

# %%
as_KW = 'Anti-selected'
as_singles = pd.Index([elt[0] for elt in test_grps[test_grps.group==as_KW].loc[:,['drug1_name','drug2_name']].values if isinstance(elt[1],float)])
print('Both (anti-selected):',as_singles.intersection(nadd_add_single_intersection).shape[0])
single_n4 = as_singles.intersection(nadd_add_single_intersection).shape[0]
# Out:
# Both (anti-selected): 16

# %%
## 144 "selected" pairs
## 120 "unselected" pairs
##  37 "anti-selected" pairs
##  36 "additional unselected" pairs

## 157 unique drugs
##  15 of these at low-dosage
## 337 drug pairs
##  79 low-dosage pairs

## 416 wells used by drug pairs
## 172 wells used by single drugs
## 588 total wells

# %%
top_consensus = test_grps[test_grps.group=='Top selected (brown)']
top_selected_singles = pd.concat([top_consensus.drug1_name.value_counts(),top_consensus.drug2_name.value_counts()],axis=1).sum(axis=1)

non_cancer = test_grps[test_grps.group=='Non-cancer']
non_cancer_singles = pd.concat([non_cancer.drug1_name.value_counts(),non_cancer.drug2_name.value_counts()],axis=1).sum(axis=1)

# %%
## 9. Unselected pairs
nonsel_KW = 'Unselected'
nonsel_MI = pd.MultiIndex.from_tuples([elt for elt in test_grps[test_grps.group==nonsel_KW].loc[:,['drug1_name','drug2_name']].values if not isinstance(elt[1],float)])
print('Unselected (pair):',nonsel_MI.shape[0])
nonsel_IND = pd.Index([elt[0] for elt in test_grps[test_grps.group==nonsel_KW].loc[:,['drug1_name','drug2_name']].values if isinstance(elt[1],float)])
print('Unselected (single):',nonsel_IND.shape[0])
# Out:
# Unselected (pair): 120
# Unselected (single): 16

# %%
single_n62 = nonsel_IND.shape[0]

# %%
fig,ax=plt.subplots(1,1,figsize=(4,3.5))
ax.bar([0,0],[1383*1382/2-28228,28228],bottom=[0,1383*1382/2-28228],color=['w','C7'],edgecolor=['k','C7'],alpha=0.5)
ax.set_xlim(-1,5)
ax.axis('off')
fig.savefig(osp.join(OUTPUT_DIR,'fig3c_first_bar.svg'))

# %%
n3=nadd_add_single_intersection.shape[0]
n2=nadd_single_only.shape[0]
n1=add_single_only.shape[0]
n0=alt_term_predictions_single.shape[0]
fig,ax=plt.subplots(1,1,figsize=(4,3.5))
ax.bar([0,0],[1383-(n0+n1+n2+n3),(n0+n1+n2+n3)],bottom=[0,1383-(n0+n1+n2+n3)],color=['w','C7'],edgecolor=['k','C7'])
ax.set_xlim(-1,5)
ax.axis('off')
fig.savefig(osp.join(OUTPUT_DIR,'fig3d_first_bar_single_drug.svg'))

# %%
# n3=nadd_add_isect.shape[0]
# n2=nadd_only_inds.shape[0]
# n1=add_only_inds.shape[0]
# n0=alt_term_predictions.shape[0]
fig,ax=plt.subplots(1,1,figsize=(4,3.5))
ax.bar([0,0,0,0],[n0,n1,n2,n3],bottom=[0,n0,n0+n1,n0+n1+n2],color=['C7','C3','C4','C5'],alpha=0.5)
ax.set_xlim(-1,5)
ax.axis('off')
fig.savefig(osp.join(OUTPUT_DIR,'fig3d_second_bar_single_drug.svg'))

# %%
fig,ax=plt.subplots(1,1,figsize=(4,3.5))
ax.bar([0,0,0,0,0],[single_n61+single_n62,single_n4,single_n2,single_n3,single_n1],
        bottom=[0,single_n61+single_n62,single_n61+single_n62+single_n4,
                single_n61+single_n62+single_n4+single_n2,single_n61+single_n62+single_n4+single_n3+single_n2],
                color=['#4DBEEE','#EDB120','w','C2','C1'],edgecolor=['#4DBEEE','#EDB120','C1','C2','C1'],alpha=0.5)
ax.set_xlim(-1,5)
ax.axis('off')
fig.savefig(osp.join(OUTPUT_DIR,'fig3d_third_bar_single_drug.svg'))

# %%
n3 = nadd_add_isect.shape[0]
n2 = nadd_only_inds.shape[0]
n1 = add_only_inds.shape[0]
n0 = alt_term_predictions.shape[0]

fig,ax=plt.subplots(1,1,figsize=(4,3.5))
ax.bar([0,0,0,0],[n0,n1,n2,n3],bottom=[0,n0,n0+n1,n0+n1+n2],color=['C7','C3','C4','C5'],alpha=0.5)
ax.set_xlim(-1,5)
ax.axis('off')
fig.savefig(osp.join(OUTPUT_DIR,'fig3c_second_bar.svg'))
np.sum([n0,n1,n2,n3])
# Out:
# 28228

# %%
print('Nonadditive only (single):',nadd_single_only.shape[0])
print('Additive only (single):',add_single_only.shape[0])
print('Intersection (single):',nadd_add_single_intersection.shape[0])
print('Single-term predictions (single):',alt_term_predictions_single.shape[0])
nadd_single_only.shape[0]+add_single_only.shape[0]+nadd_add_single_intersection.shape[0]+alt_term_predictions_single.shape[0]
# Out:
# Nonadditive only (single): 163
# Additive only (single): 70
# Intersection (single): 809
# Single-term predictions (single): 70
# 1112

# %%
n4 = 51
n3 = 38
n2 = 68
n1 = 36
n0 = 154
fig,ax=plt.subplots(1,1,figsize=(4,3.5))
ax.bar([0,0,0,0,0],[n0,n1,n2,n3,n4],bottom=[0,n0,n0+n1,n0+n1+n2,n0+n1+n2+n3],color=['#4DBEEE','#EDB120','w','C2','C1'],edgecolor=['#4DBEEE','#EDB120','C1','C2','C1'],alpha=0.5)
ax.set_xlim(-1,5)
ax.axis('off')
fig.savefig(osp.join(OUTPUT_DIR,'fig3c_third_bar.svg'))
print(np.sum([n0,n1,n2,n3,n4]))
# Out:
# 347

# %% [markdown]
# dictionaries mapping the cell line & drug to
# 1. `cl_drg_data_d`: a list of viability data
# 2. `cl_drg_inds_d`: a list of tuples of the form (plate_well,(layout,replicate))

# %%
## convert sel_df_comb into dictionaries that make the 
## viability data accessible by drug pair
cl2abbr = {'CH-157MN':'CH','GBM12':'12','GBM43':'43','IOMM-LEE':'Io','LN-229':'LN'}
cl_drg_data_d = {}
cl_drg_inds_d = {}
for CL,clabbr in cl2abbr.items():
    if CL=='GBM12':
        continue
    cl_data = sel_df_comb.xs(clabbr,level=0,axis=1)
    ## need to get A/B / 1/2/3
    drg_data_d = defaultdict(list)
    drg_inds_d = defaultdict(list)
    for aorb,cols in cl_data.groupby(level=0,axis=1):
        cols2 = cols.columns.droplevel(0)
        if aorb == 'A':
            pver = 'alpha'
            GB =  GB_alpha
            drg_well_d = {}
            drg_well_d.update(dict([(k,[v]) for k,v in sel_inds_d.items()]))
            drg_well_d.update(dict([(k,[v]) for k,v in sel_inds_singles.items()]))
            drg_well_d.update(dict([(k,[v]) for k,v in noncanc_alpha_d.items()]))
        elif aorb == 'B':
            pver = 'beta'
            GB =  GB_beta
            drg_well_d = {}
            drg_well_d.update(dict([(k,[v]) for k,v in noncanc_beta_d.items()]))
            drg_well_d.update(dict([(k,[v]) for k,v in ld_inds_d.items()]))
            drg_well_d.update(dict([(k,[v]) for k,v in nonsel_inds_d.items()]))
            drg_well_d.update(dict([(k,[v]) for k,v in antisel_well_d.items()]))
        ## correct the drug_well_d
        rep_well_d = dict([(ii,drg_well_d.copy()) for ii in range(1,4)])        
        ## using rep_well_d, iterate over all drugs in drg_well_d and assign (well,aorb,rep) to each available drug pair
        for k in drg_well_d.keys():
            if isinstance(k,tuple):
                kk = tuple(sorted(k)) if not k==('mycophenolic acid','fenbendazole') else k
            else:
                kk = k
            for num,cwell_d in rep_well_d.items():
                if kk in cwell_d.keys():
                    for wl,vol in cwell_d[kk]:
                        if vol==40:
                            drg_data_d[kk].append(cl_data.loc[wl,(aorb,str(num))])
                            drg_inds_d[kk].append((wl,(aorb,str(num))))
                        else:
                            if isinstance(kk,tuple):
                                kkp = tuple([elt+'_ld' for elt in kk])
                            else:
                                kkp = kk+'_ld'
                            drg_data_d[kkp].append(cl_data.loc[wl,(aorb,str(num))])
                            drg_inds_d[kkp].append((wl,(aorb,str(num))))
    drg_data_d = dict(drg_data_d)
    drg_inds_d = dict(drg_inds_d)
    cl_drg_data_d[CL] = drg_data_d
    cl_drg_inds_d[CL] = drg_inds_d

# %%
antisel_pairs = [elt for elt in antisel_well_d.keys() if isinstance(elt,tuple)]
nonsel_pairs = [kk for kk in nonsel_inds_d.keys() if isinstance(kk,tuple)]
nc_alpha_pairs = [elt  for elt in noncanc_alpha_d.keys() if isinstance(elt,tuple)]
nc_beta_pairs = [elt  for elt in noncanc_beta_d.keys() if isinstance(elt,tuple)]
noncanc_pairs = nc_alpha_pairs+nc_beta_pairs
ld_pairs = [elt for elt in ld_inds_d.keys() if isinstance(elt,tuple)]
colkw = 'loewe_12'
## the following drug pairs are shared between the top and non-cancer pairs 
shared_l = [('calcipotriol', 'lomefloxacin'), ('chir-99021', 'olopatadine'), ('chir-99021', 'sumatriptan'),
            ('diacerein', 'sgc-cbp30'), ('digitoxin', 'digoxin'), ('digoxin', 'pivmecillinam'),
            ('digoxin', 'sgc-cbp30'), ('miconazole', 'sulfamethoxypyridazine'), ('pitavastatin', 'pmsf'),]

top_sel = list(set(index_dict[('all','all','top')])-set(shared_l))
noncanc_l = [ kk for kk in noncanc_alpha_d.keys() if isinstance(kk,tuple)]+shared_l
lbl_kw_d = {'top':top_sel,'anti':antisel_pairs,
            'random':nonsel_pairs,'noncanc':noncanc_l}

comb_pred = pd.read_excel(osp.join(INPUT_DIR,'DatasetS3_combined_predictions.xlsx'),
                          engine='openpyxl',index_col=[0,1],header=[0,1])

# %% [markdown]
# ### Fig. S2

# %% [markdown]
# #### Script to generate the mechanism of action-to-drug matrix

# %%
## invert the drug --> moa mapping to moa --> drug_list
moa2drug = defaultdict(list)
single =test_grps[(test_grps.drug2_name.isna())&(test_grps.drug1_uM==10)]
for drg,moa_l in drug2moa.items():
    if isinstance(moa_l,str):
        moa2drug[moa_l].append(drg)
    else:
        for moa in moa_l:
            moa2drug[moa].append(drg)
moa2drug = dict(moa2drug)

## get counts of moa
moa_counts = {}
for k,v in moa2drug.items():
    moa_counts[k]=len(v)
moa_counts_ser = pd.Series(moa_counts)

## low dosage drugs
moa2drug_ld = defaultdict(list)
single_ld =test_grps[(test_grps.drug2_name.isna())&(test_grps.drug1_uM<10)]
for rn,row in single_ld.iterrows():
    drg = row.loc['drug1_name']
    moa_l = drug2moa[drg]
    if isinstance(moa_l,str):
        moa2drug_ld[moa_l].append(drg)
    else:
        for moa in moa_l:
            moa2drug_ld[moa].append(drg)
moa2drug_ld = dict(moa2drug)
moa_counts_ld = {}
for k,v in moa2drug_ld.items():
    moa_counts_ld[k]=len(v)
moa_counts_ld_ser = pd.Series(moa_counts_ld)

## construct matrix of (moa \times drug group)
moa2dgrp = defaultdict(list)
for moa in moa_counts_ser[moa_counts_ser>1].index:
    drg_l = moa2drug[moa]
    for drg in drg_l:
        grp =single[single.drug1_name==drg]['group'].iloc[0]
        moa2dgrp[(moa,grp)].append(drg)
    if moa in moa_counts_ld_ser.index:
        drg_ld_l = moa2drug_ld[moa]
        for drg_ld in drg_ld_l:
            moa2dgrp[(moa,'Low-dosage')].append(drg_ld)
for moa in moa_counts_ser[moa_counts_ser==1].index:
    drg = moa2drug[moa][0]
    moa2dgrp[(moa,'Other')].append(drg)
            
moa2dgrp = dict(moa2dgrp)

moadgrp_counts = {}
for kw,ll in moa2dgrp.items():
    moadgrp_counts[kw]=len(set(ll))
moa_dgrp_df = pd.Series(moadgrp_counts).unstack().fillna(0)
aaa = moa_dgrp_df.T[moa_dgrp_df.columns!='Other'].T
moa_dgrp_df2 = aaa[aaa.sum(axis=1)>0]

# %%
moa_dgrp_df2.columns = ['Anti-selected','Low-dosage','Non-cancer','Top selected','Unselected']

# %% [markdown]
# `moa_dgrp_df`: is the matrix that counts the number of drugs for each group
#
# `moa_dgrp_df2`: is the matrix that counts the number of drugs for each group, excluding the "Other" category.

# %% [markdown]
# #### Fig. S2A

# %%
srt_cols = moa_dgrp_df2.sum().sort_values(ascending=False).index
clr_l = ['C1','C2','C8','C9','C6']
grplbls = ['Top selected','Non-cancer','Anti-selected','Unselected','Low-dosage']
grpclr_d = dict(zip(grplbls,clr_l))
moafig,moaax = plt.subplots(1,1,dpi=180,figsize=(4.5,3))
baseline = np.zeros(moa_dgrp_df2.shape[0])
for nm,col in moa_dgrp_df2.loc[:,srt_cols].sort_values('Low-dosage',ascending=False).items():
    if nm=='Other':
        continue
    lbl = nm.split(' (')[0] if 'purple' in nm else nm    
    #scol = col[(moa_dgrp_df.Other-moa_dgrp_df.sum(axis=1))<0]
    moaax.bar(np.arange(col.shape[0]),col,bottom=baseline,label=lbl,color=grpclr_d[nm],alpha=0.7)
    baseline+=col.values
moaax.set_xticks(np.arange(moa_dgrp_df2.shape[0]))
moaax.set_xticklabels(moa_dgrp_df2.sort_values('Low-dosage',ascending=False).index,size=6,rotation=45,horizontalalignment='right')
moaax.set_yticks(np.arange(0,21,5))
moaax.set_yticklabels(np.arange(0,21,5),size=6)
moaax.set_xlim(-0.75,moa_dgrp_df2.shape[0]-0.25)
moaax.set_xlabel('Mechanism of action',size=8)
moaax.set_ylabel('Count',size=8)
moafig.savefig(osp.join(OUTPUT_DIR,'figS2a_moa_counts.svg'))

# %% [markdown]
# #### Fig. S2A (inset)

# %%
moafig2 = plt.figure(figsize=(3,1.5),dpi=180)
moaax2 = moafig2.add_axes([.15,.2,.8,.75])
colsums = moa_dgrp_df2.sum()

xlbls = []
for ii,(nm,col) in enumerate(colsums.sort_values(ascending=False).items()):
    lbl = nm.split(' (')[0] if 'purple' in nm else nm
    xlbls.append(lbl)
    moaax2.bar([ii],[col],color=grpclr_d[nm],alpha=0.7)
    
moaax2.set_xticks(np.arange(len(xlbls)))
moaax2.set_xticklabels(xlbls,size=6,rotation=45,horizontalalignment='right')

moaax2.set_xlabel('Drug group',size=8)
moaax2.set_ylabel('Count',size=8)
moafig2.savefig(osp.join(OUTPUT_DIR,'figS2a_inset_drug_group_counts_inset.svg'))

# %%
single.loc[:,'group'] = single.loc[:,'group'].replace('Top selected (purple)','Top selected').copy()
# Out:
# /var/folders/cr/tmh4xbn13gv37d49tyk2lyx80000gn/T/ipykernel_3940/2874673092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single.loc[:,'group'] = single.loc[:,'group'].replace('Top selected (purple)','Top selected').copy()

# %%
## plot the viability data
moa2dgrp_all = defaultdict(list)
for moa in moa_counts_ser.index:
    drg_l = moa2drug[moa]
    for drg in drg_l:
        grp =single[single.drug1_name==drg]['group'].iloc[0]
        moa2dgrp_all[(moa,grp)].append(drg)
    if moa in moa_counts_ld_ser.index:
        drg_ld_l = moa2drug_ld[moa]
        for drg_ld in drg_ld_l:
            moa2dgrp_all[(moa,'Low-dosage')].append(drg_ld)
            
moa2dgrp_all = dict(moa2dgrp_all)

ii = 0
sel_df_comb = sel_df_comb.T[sel_df_comb.columns.get_level_values(0)!='12'].T ## viability data (obtained earlier)
dgrp_viability_d = defaultdict(list) ## container for the viability data
grplbls2 = ['Low-dosage','Top selected','Non-cancer','Anti-selected','Unselected','Other']
grpclr_d['Other']='#808080'
dgrp_shift_d = dict(zip(grplbls2,0.1*np.arange(len(grplbls2))))
moa2xval = dict([(yy,xx) for xx,yy in enumerate(moa_dgrp_df2.sort_values('Low-dosage',ascending=False).index)])
cl_title_d = {'43':'GBM43','LN':'LN-229','CH':'CH-157MN','Io':'IOMM-LEE'}
moa2xval['Other']=len(moa2xval.keys())
for (moa,dgrp),drg_l in moa2dgrp_all.items():
    layout = single if dgrp != 'Low-dosage' else single_ld
    if moa in moa2xval.keys():
        for drg in drg_l:
            if not drg in layout.drug1_name.unique():
                continue
            pl,wl = layout[layout.drug1_name==drg].index[0]
            pp = 'A' if pl=='alpha' else 'B'
            avg_via_cl = sel_df_comb.xs(pp,axis=1,level=1).loc[wl].groupby(level=0).mean()
            std_via_cl = sel_df_comb.xs(pp,axis=1,level=1).loc[wl].groupby(level=0).std()
            for cl,via in avg_via_cl.items():
                dgrp_viability_d[(cl,dgrp,'xvals')].append(moa2xval[moa]+dgrp_shift_d[dgrp]+np.random.rand()*1e-2)
                dgrp_viability_d[(cl,dgrp,'yvals')].append(via)
                dgrp_viability_d[(cl,dgrp,'ystd')].append(std_via_cl.loc[cl])
    else:
        for drg in drg_l:
            if not drg in layout.drug1_name.unique():
                continue
            pl,wl = layout[layout.drug1_name==drg].index[0]
            pp = 'A' if pl=='alpha' else 'B'
            avg_via_cl = sel_df_comb.xs(pp,axis=1,level=1).loc[wl].groupby(level=0).mean()
            std_via_cl = sel_df_comb.xs(pp,axis=1,level=1).loc[wl].groupby(level=0).std()
            for cl,via in avg_via_cl.items():
                dgrp_viability_d[(cl,'Other','xvals')].append(moa2xval['Other']+dgrp_shift_d[dgrp]+np.random.rand()*1e-2)
                dgrp_viability_d[(cl,'Other','yvals')].append(via)
                dgrp_viability_d[(cl,'Other','ystd')].append(std_via_cl.loc[cl])
dgrp_viability_d = dict(dgrp_viability_d)

# %% [markdown]
# #### Fig. S2B

# %%
fig,ax_l = plt.subplots(4,1,dpi=300,sharex=True,figsize=(7.5,5))
for ii,(cl,title) in enumerate(sorted(cl_title_d.items(),key=lambda I: I[1])):
    ax = ax_l[ii]
    for dgrp in grplbls2:
        lbl = dgrp
        xvals = dgrp_viability_d[(cl,dgrp,'xvals')]
        yvals = dgrp_viability_d[(cl,dgrp,'yvals')]
        yerr = dgrp_viability_d[(cl,dgrp,'ystd')]
        #ax.errorbar(xvals,yvals,yerr=yerr,ls='',marker='.',ecolor=grpclr_d[dgrp],mfc=grpclr_d[dgrp],mec='none',label=dgrp)
        ax.scatter(xvals,yvals,marker='.',color=grpclr_d[dgrp],alpha=0.5,label=lbl)
    ax.set_title(title,size=8)
    ax.set_ylabel('Viability',size=8)
    ax.set_yscale('log')
    plt.setp(ax.get_yticklabels(),size=6)
    if ii==0:
        leg = ax.legend(frameon=False,prop={'size':6},ncol=3)
    
ax.set_xticks(np.arange(len(moa2xval.keys())))
ax.set_xticklabels(moa2xval.keys(),size=6,rotation=45,horizontalalignment='right')
ax.set_xlabel('Mechanism of action',size=8)
plt.tight_layout()
fig.savefig(osp.join(OUTPUT_DIR,'figS2b_data.svg'))

# %% [markdown]
# #### Mechanism of Action statistics

# %%
## get the drug to moa matrix, needed for constructing the statistical model. "A" in Eq. (S26)
drg_moa_matrix = defaultdict(int)
for drg,moa_l in drug2moa.items():
    if isinstance(moa_l,str):
        MOA='Other' if moa_counts_ser.loc[moa_l]==1 else moa_l
        drg_moa_matrix[(drg,MOA)]+=1
    else:
        for moa in moa_l:
            MOA='Other' if moa_counts_ser.loc[moa]==1 else moa
            drg_moa_matrix[(drg,MOA)]+=1
                
    
drg_moa_matrix = dict(drg_moa_matrix)
drg_moa_matrix2 = pd.Series(drg_moa_matrix).unstack().fillna(0)
drg_moa_matrix2

drg_avgvia_d = {} ## average viability measurements
for drg in single.drug1_name.unique():
    pl,wl = single[single.drug1_name==drg].index[0]
    pp = 'A' if pl=='alpha' else 'B'
    avg_via_cl = sel_df_comb.xs(pp,axis=1,level=1).loc[wl].groupby(level=0).mean()
    drg_avgvia_d[drg]=np.log(avg_via_cl)
drg_avgvia_df = pd.DataFrame(drg_avgvia_d)
Q = drg_moa_matrix2.T@drg_moa_matrix2
C = (drg_avgvia_df@drg_moa_matrix2).T
u = np.linalg.solve(Q,C)
est_vals = drg_moa_matrix2@u ## estimated viability based on mechanism of action
est_vals.columns = drg_avgvia_df.index
act_rsqr = 1-(drg_avgvia_df.T-est_vals).var()/drg_avgvia_df.T.var() ## actual R^2

# %%
## randomly reshuffle dat
cpy = drg_avgvia_df.copy()
rnd_rsqr_l = []
for ii in range(1000):
    np.random.shuffle(cpy.T.values)
    C_rnd = (cpy@drg_moa_matrix2).T
    u_rnd = np.linalg.solve(Q,C_rnd)
    est_vals_rnd = drg_moa_matrix2@u_rnd
    est_vals_rnd.columns = drg_avgvia_df.index
    rnd_rsqr = 1-(cpy.T-est_vals_rnd).var()/cpy.T.var()
    rnd_rsqr_l.append(rnd_rsqr)
rnd_rsqr_df = pd.concat(rnd_rsqr_l,axis=1) ## random R^2 distribution.

# %%
## the next line prints out the p-values
pd.Series(norm.sf((act_rsqr-rnd_rsqr_df.mean(axis=1))/rnd_rsqr_df.std(axis=1))*2,index=[cl_title_d[cc] for cc in act_rsqr.index]).sort_index()
# Out:
# CH-157MN    7.362412e-15
# GBM43       1.112829e-09
# IOMM-LEE    4.679670e-12
# LN-229      1.399951e-12
# dtype: float64

# %% [markdown]
# #### Fig. S2C

# %%
srt_clks = [clk for clk,clt in sorted(cl_title_d.items(),key=lambda it: it[1])]
rnd_rsqr_df = rnd_rsqr_df.loc[srt_clks]
fig,ax = plt.subplots(1,1,dpi=180,figsize=(1.5,4))
ax.boxplot([rnd_rsqr_df.iloc[ii,:] for ii in range(rnd_rsqr_df.shape[0])],
           patch_artist=True,
           boxprops={'facecolor':'C7','edgecolor':'C7','alpha':0.5},
           whiskerprops={'color':'C7','alpha':0.5},capprops={'color':'C7','alpha':0.5},
           flierprops={'marker':'.','markerfacecolor':'C7','markeredgecolor':'C7','alpha':0.9},
           positions=np.arange(rnd_rsqr_df.shape[0]),
           widths=np.ones(rnd_rsqr_df.shape[0])*0.8,
          )
ax.plot(np.arange(act_rsqr.shape[0]),act_rsqr.loc[srt_clks],ls='',marker='*')
ax.set_xticklabels(sorted(cl_title_d.values()),rotation=30,size=6,horizontalalignment='right')
plt.setp(ax.get_yticklabels(),size=6)
ax.set_xlabel('Cell line')
ax.set_ylabel(r'$R^2_{\rm MOA}$')
fig.savefig(osp.join(OUTPUT_DIR,'figS2c_stat_test_boxplot.svg'))

# %% [markdown]
# ### Fig. 5 A and B (venn diagrams)

# %% [markdown]
# #### Fig. 5A
# Note: this includes drugs selected via optimization with respect to an objective function consisting of the cell-behavior (first) term only and the cell-growth term only as well as both terms. The latter case is considered in the text.

# %%
set_d = {}
for (meth,vari),col in comb_pred.items():
#     vari_nm = vari_nm_d[vari]
    nz_col = col[~col.isna()]
    inds = [tuple(sorted(elt)) for elt in nz_col.index.tolist()]
    set_d[(meth,vari)]=set(inds)

fig,ax_l = plt.subplots(1,2,dpi=180)
method_lbl_d = {'0.00':'Behavior','0.79':'Blended','1.57':'Growth'}
for yy,tp in enumerate(['nonadditive','additive']):    
    venn3([set(vv) for kk,vv in set_d.items() if kk[0]==tp],
          [method_lbl_d[kk[1]] for kk in set_d.keys() if kk[0]==tp],
          [f'C{xx:d}' for xx in range(3)],alpha=0.5,ax=ax_l[yy])
    ax_l[yy].set_title(tp)
fig.savefig(osp.join(OUTPUT_DIR,'additive_nonadditive_venn_diagrams_exp.svg'))

# %%
fig,ax = plt.subplots(1,1,figsize=(2,1),dpi=180)
venn2([set_d[('additive', '0.79')],set_d[('nonadditive', '0.79')]], ['Additive','Nonadditive'],
        ['C3','C4'],alpha=0.5,ax=ax)
fig.savefig(osp.join(OUTPUT_DIR,'fig5a_additive_nonadditive_overlap.svg'))

# %% [markdown]
# #### More comparisons

# %%
fig2,ax_l2 = plt.subplots(1,3,dpi=180)
for zz,mthd in enumerate(['0.00','0.79','1.57']):
    venn2([set(vv) for kk,vv in set_d.items() if kk[1]==mthd],
         [kk[0] for kk in set_d.keys() if kk[1]==mthd],
         ['C%d' % zz for dum in range(2)],alpha=0.5,ax=ax_l2[zz])
fig2.savefig(osp.join(OUTPUT_DIR,'method_venn_diagrams.svg'))

# %% [markdown]
# ### Fig. 5C–E (AUC example & method boxplots)

# %% [markdown]
# #### Fig. 5C

# %%
comb_pred
# Out:
#                             additive                     nonadditive  \
#                                 0.00      0.79      1.57        0.00
# doxorubicin   gsk1120212    3.933225  3.948555  3.150929    4.343792
# ciclopirox    doxorubicin   3.887023  3.722038  3.774632    4.745340
# doxorubicin   torin 2       4.048847  5.168607  0.503311    5.991915
# ciclopirox    gsk1120212    3.845363  3.848029  2.229836    5.165437
# doxorubicin   topotecan     3.854720  2.724922  2.293670    3.470240
# ...                              ...       ...       ...         ...
# ic-261        rifapentine        NaN       NaN       NaN         NaN
# melphalan     ofloxacin          NaN       NaN       NaN         NaN
# acefylline    lansoprazole       NaN       NaN       NaN    0.000571
# brd-k63784565 sgc-cbp30          NaN       NaN       NaN         NaN
# bms-387032    deflazacort        NaN       NaN       NaN    0.000197
#
#
#                                 0.79      1.57
# doxorubicin   gsk1120212    4.756909  9.074633
# ciclopirox    doxorubicin   5.705205  6.513023
# doxorubicin   torin 2       6.290748  5.268310
# ciclopirox    gsk1120212    4.142441  7.008207
# doxorubicin   topotecan     3.877377  7.024954
# ...                              ...       ...
# ic-261        rifapentine   0.000663       NaN
# melphalan     ofloxacin     0.000576       NaN
# acefylline    lansoprazole       NaN       NaN
# brd-k63784565 sgc-cbp30     0.000287       NaN
# bms-387032    deflazacort        NaN       NaN
#
# [28228 rows x 6 columns]

# %%
fnbase_l = ['lodo_mu_sig_%s_dataset.pkl','ctpair_3fold_mu_sig_%s_celltypepair.pkl']
DATA = pd.DataFrame(cl_drg_data_d['CH-157MN']).T
nonadd_IS = comb_pred.loc[:,('nonadditive','0.79')].sort_values(ascending=False).index.intersection(DATA.index)
add_IS = comb_pred.loc[:,('additive','0.79')].sort_values(ascending=False).index.intersection(DATA.index)
v1 = DATA.loc[nonadd_IS].mean(axis=1)
v1r = comb_pred.loc[:,('nonadditive','0.79')].rank(ascending=False,pct=True).loc[nonadd_IS]
v2 = DATA.loc[add_IS].mean(axis=1)
v2r = comb_pred.loc[:,('additive','0.79')].rank(ascending=False,pct=True).loc[add_IS]
sel_v1 = v1[~v1r.isna()]
sel_v2 = v2[~v2r.isna()]
common = sel_v1.index.intersection(sel_v2.index)
def alphasrt_multiindex(MI):
    alphasrt_inds = []
    for (a,b) in MI:
        if a<b:
            alphasrt_inds.append((a,b))
        else:
            alphasrt_inds.append((b,a))
    return pd.MultiIndex.from_tuples(alphasrt_inds)
NRREP = 100

auc_info_d = {}
for CL,drg_data_d in cl_drg_data_d.items():
    DATA = pd.DataFrame(drg_data_d).T
    sel_TF = [isinstance(ind,tuple) and not ind[0].endswith('_ld') for ind in DATA.index]
    DATA.index = pd.MultiIndex.from_tuples([k if isinstance(k,tuple) else (k,'dmso') for k in DATA.index])
    #VTHR=DATA.mean(axis=1).describe().loc['50%']
    VTHR= DATA[sel_TF].mean(axis=1).median()
    for fnbase in fnbase_l[:1]:
        lbl = 'lodo' if fnbase.startswith('lodo') else 'ctpair'
        for objval in ['0.00','0.79','1.57']:
            if CL=='LN-229' and objval=='0.79':
                fig,ax = plt.subplots(2,1,dpi=180,figsize=(1.5,4))
            fpr_l = []
            tpr_l = []
            thrl_l = []
            IS_l = []
            var_pred_l = []
            for kk in range(2):
                bsubstr,predstr = ('nonadd','nonadditive') if kk!=0 else ('linear','additive')
                fntot = osp.join(INPUT_DIR,fnbase)
                xdiffs = pd.read_pickle(fntot % bsubstr)
                cmb_diffs = xdiffs.xs(objval,level=2).copy()
                pred = comb_pred.loc[:,(predstr,objval)]
                #pred = pred[~pred.isna()]
                cmb_diffs.index = alphasrt_multiindex(cmb_diffs.index)
                IS = pred[~pred.isna()].index.intersection(DATA.index)
                IS_l.append(IS)
                var_pred_l.append((cmb_diffs,pred,predstr))
            common = IS_l[0].union(IS_l[1])
            common_stats = DATA.loc[common].T.describe().T.loc[:,'mean':'std']
            rnd_vals_l = []
            auc_dd = defaultdict(list)
            for kk,(cmb_diffs,pred,predstr) in enumerate(var_pred_l):
                fact= 6 if fnbase.startswith('lodo') and kk==0 else 1
                duma = pred.loc[common].sort_values(ascending=False) #.fillna(0)
                wtrank = (duma/duma.sum()).cumsum()
                wtrank_l = []
                for elt in common.difference(cmb_diffs.index):
                    cmb_diffs.loc[elt,'mu'] = np.nan
                    cmb_diffs.loc[elt,'sig'] = np.nan
                for nn in range(NRREP):
                    rnd_val_d = {}
                    dum = pred.loc[common]+fact*cmb_diffs.loc[common,'sig']*np.random.randn(common.shape[0])
                    rnd_wtrank = (dum/dum.sum()).sort_values(ascending=False).cumsum().loc[common]
                    if kk==0:
                        rnd_vals = common_stats.loc[common,'mean']+np.random.randn(common_stats.shape[0])*common_stats.loc[common,'std']
                        rnd_vals_l.append(rnd_vals)
                    else:
                        rnd_vals = rnd_vals_l[nn]
                    SEL = ~rnd_wtrank.loc[common].isna()
                    rfpr,rtpr,rthrl = roc_curve(common_stats[SEL].loc[:,'mean']<VTHR,1-rnd_wtrank[SEL])
                    auc_dd[predstr].append(auc(rfpr,rtpr))
                    wtrank_l.append(rnd_wtrank)
                    ## need to calculate the AUC distribution here
                wtrank_sig = pd.concat(wtrank_l,axis=1).std(axis=1)/10.
                fpr,tpr,thrl = roc_curve(common_stats[~wtrank.loc[common].isna()].loc[:,'mean']<VTHR,1-wtrank.loc[common][~wtrank.isna()])
                fpr_l.append(fpr)
                tpr_l.append(tpr)
                thrl_l.append(thrl)
                act_auc = auc(fpr,tpr)
                auc_dd[predstr].append(act_auc)
                if CL=='LN-229' and objval=='0.79':
                    ax[0].errorbar(wtrank.loc[common],common_stats.loc[:,'mean'],
                                 xerr=wtrank_sig.loc[common],yerr=common_stats.loc[:,'std'],fmt='C%d.' % (kk+3),ms=4,alpha=0.5)
                    ax[1].plot(fpr,tpr,label='%s : %.02f' % (predstr,act_auc),color='C%d' % (kk+3))
            auc_d = dict(auc_dd)
            for kk,vv in auc_d.items():
                auc_info_d[(CL,objval,kk)]=vv
            if CL=='LN-229' and objval=='0.79':
                ax[0].set_yscale('log')
                ax[0].set_xticks([0,0.5,1])
                ax[0].set_ylabel('Viability',size=8)
                ax[0].set_xlabel('Weighted rank',size=8)
                ax[0].axhline(VTHR,ls='--',color='C7')
                ind1 = 4
                ax[0].axvline((1-thrl_l[1][ind1]),ls='-',color='C7')
                plt.setp(ax[0].get_xticklabels(),size=6)
                plt.setp(ax[0].get_yticklabels(),size=6)
                ax[1].set_ylabel('TPR',size=8)
                ax[1].set_xticks([0,0.5,1])
                ax[1].set_xlabel('FPR',size=8)
                ax[1].plot(fpr_l[1][ind1:ind1+1],tpr_l[1][ind1:ind1+1],color='C4' ,marker=(5,1,0))
                ind0 = np.argmin(np.abs((1-np.asarray(thrl_l[0]))-(1-thrl_l[1][ind1])))
                ax[1].plot(fpr_l[0][ind0:ind0+1],tpr_l[0][ind0:ind0+1],color='C3',marker=(5,1,0))                 
                ax[1].legend(title='AUC',frameon=False,prop={'size':6})
                ax[1].plot(np.linspace(0,1),np.linspace(0,1),ls='--',color='C7')
                plt.setp(ax[1].get_xticklabels(),size=6)
                plt.setp(ax[1].get_yticklabels(),size=6)
                fig.tight_layout()
                fig.savefig(osp.join(OUTPUT_DIR,'fig5cd_example_LN-229_0.79_trend.svg'))
kw_df = pd.DataFrame(auc_info_d.keys())

# %% [markdown]
# #### Fig. 5E

# %%
fig2,ax2a = plt.subplots(1,4,dpi=180,figsize=(3.5,1.5),sharey=True,sharex=True)
objval_clr_d = {'0.00':'C0','0.79':'C1','1.57':'C2'}
objval_str_d = {'0.00':'Behavior','0.79':'Blended','1.57':'Growth'}
objval_num_d = {'0.00':0,'0.79':1,'1.57':2}
kk_num_d = {'additive':0,'nonadditive':1}
auc_tstat_d = {}
for ii,CL in enumerate(kw_df.iloc[:,0].unique()):    
    ax2 = ax2a[ii]
    ax2.set_title(CL,size=8)
    if ii==0:
        ax2.set_ylabel('AUC',size=8)
        ax2.set_ylim(0,1)
        plt.setp(ax2.get_yticklabels(),size=6)
    clr_dat_d = defaultdict(list)
    for (CLz,objval,kk) in kw_df[kw_df.iloc[:,0]==CL].values:
        clr = objval_clr_d[objval]
        pos=2*objval_num_d[objval]+kk_num_d[kk]
        clr_dat_d[clr].append((auc_info_d[(CL,objval,kk)],pos,kk))
    for (CLx,objval1,kk1),(CLy,objval2,kk2) in combs(kw_df[kw_df.iloc[:,0]==CL].values,2):
        auc_l1 = auc_info_d[(CL,objval1,kk1)]
        auc_l2 = auc_info_d[(CL,objval2,kk2)]
        tstat,pval = ranksums(auc_l1,auc_l2)
        auc_tstat_d[(CL,objval1,kk1,objval2,kk2,'rstat')]=tstat
        auc_tstat_d[(CL,objval1,kk1,objval2,kk2,'pval')]=pval
    clr_dat_d = dict(clr_dat_d)
    clr_l = []
    box_l = []
    for clr,dat in clr_dat_d.items():
        data_l,pos_l,lbl_l = zip(*dat)
        box = ax2.boxplot(data_l,positions=pos_l,labels=lbl_l,widths=0.6,patch_artist=True,
                         notch=False,sym='%s.' % clr,boxprops={'color':clr,'alpha':0.5},
                         whiskerprops={'color':'k'}, capprops={'color':'k'},
                         medianprops={'color':'C3'},flierprops={'alpha':0.5,'markeredgecolor':None})
        box_l.append(box)
        clr_l.append(clr)
    for clr,bplot in zip(clr_l,box_l):
        sclr = [box.set_color(clr) for box in bplot['boxes']]
        sal = [box.set_alpha(0.5) for box in bplot['boxes']]
    plt.setp(ax2.get_xticklabels(),rotation=90,size=6)
fig2.savefig(osp.join(OUTPUT_DIR,'ranked_viability_auc.svg')) ## this figure breaks the result down by each method
auc_tstat_ser=pd.Series(auc_tstat_d)
auc_tstat_df = auc_tstat_ser.unstack(0)
auc_tstat_df.to_excel(osp.join(OUTPUT_DIR,'ranked_viability_auc_tstats.xlsx'))

# %%
fig2,ax2 = plt.subplots(1,1,dpi=180,figsize=(3.5,1.5))
#objval_clr_d = {'0.79':'C1'}
#objval_str_d = {'0.79':'Blended'}
CL_num_d = {'CH-157MN':0,'GBM43':1,'IOMM-LEE':2,'LN-229':3}
clr = 'C1'

#kk_num_d = {'Additive':0,'Nonadditive':1}
auc_tstat_d = {}
ax2.set_ylabel('AUC',size=8)
ax2.set_ylim(0,1)
ax2.set_yticks(np.linspace(0,1,6))
plt.setp(ax2.get_yticklabels(),size=6)
add_trend = [auc_info_d[(CL,'0.79','additive')] for CL in kw_df.iloc[:,0].unique()]
add_pos = [2*CL_num_d[CL] for CL in kw_df.iloc[:,0].unique()]
nadd_trend = [auc_info_d[(CL,'0.79','nonadditive')] for CL in kw_df.iloc[:,0].unique()]
nadd_pos = [2*CL_num_d[CL]+1 for CL in kw_df.iloc[:,0].unique()]

add_box = ax2.boxplot(add_trend,positions=add_pos,widths=0.6,patch_artist=True,
                    notch=False,boxprops={'facecolor':'C3','edgecolor':'C3','alpha':0.9},
                    whiskerprops={'color':'C3','alpha':0.9}, capprops={'color':'C3','alpha':0.9},
                    medianprops={'color':'C1'},
                    flierprops={'alpha':0.9,'marker':'.','markerfacecolor':'C3','markeredgecolor':'none'})
nadd_box = ax2.boxplot(nadd_trend,positions=nadd_pos,widths=0.6,patch_artist=True,
                    notch=False,boxprops={'facecolor':'C4','edgecolor':'C4','alpha':0.9},
                    whiskerprops={'color':'C4','alpha':0.9}, capprops={'color':'C4','alpha':0.9},
                    medianprops={'color':'C1'},
                    flierprops={'alpha':0.9,'marker':'.','markerfacecolor':'C4','markeredgecolor':'none'})
xtls = list(CL_num_d.keys())
xts = 0.5+2*np.arange(len(xtls))
ax2.set_xticks(xts)
ax2.set_xticklabels(xtls,size=6)
print(ax2.get_xlim())
ax2.axhline(0.5,ls='--',color='C7',alpha=0.7)
ax2.axvspan(1.5,3.5,color='C7',alpha=0.1)
ax2.axvspan(5.5,7.5,color='C7',alpha=0.1)
for ii,CL in enumerate(kw_df.iloc[:,0].unique()):    
    ## ax2.set_title(CL,size=8)
    pos=2*CL_num_d[CL]+kk_num_d[kk]
    clr_dat_d = defaultdict(list)
    for (CLx,objval1,kk1),(CLy,objval2,kk2) in combs(kw_df[(kw_df.iloc[:,0]==CL)&(kw_df.iloc[:,1]=='0.79')].values,2):
        auc_l1 = auc_info_d[(CL,objval1,kk1)]
        auc_l2 = auc_info_d[(CL,objval2,kk2)]
        tstat,pval = ranksums(auc_l1,auc_l2)
        auc_tstat_d[(CL,objval1,kk1,objval2,kk2,'rstat')]=tstat
        auc_tstat_d[(CL,objval1,kk1,objval2,kk2,'pval')]=pval
    clr_l = []
    box_l = []
fig2.savefig(osp.join(OUTPUT_DIR,'fig5e_ranked_viability_auc_singlemethod.svg'))
auc_tstat_ser=pd.Series(auc_tstat_d)
auc_tstat_df = auc_tstat_ser.unstack(0)
auc_tstat_df.to_excel(osp.join(OUTPUT_DIR,'ranked_viability_auc_tstats_singlemethod.xlsx'))
# Out:
# (-0.5, 7.5)

# %%
auc_tstat_df
# Out:
#                                           CH-157MN         GBM43  \
# 0.79 additive 0.79 nonadditive pval   1.222199e-34  1.186377e-34
#                                rstat -1.227577e+01 -1.227818e+01
#
#                                           IOMM-LEE        LN-229
# 0.79 additive 0.79 nonadditive pval   1.500119e-33  1.186377e-34
#                                rstat -1.207116e+01 -1.227818e+01

# %% [markdown]
# #### Code to calculate the synergy/${\rm IC}_{50}$ statistics

# %%
## v_{LA} threshold for the change in viability
BP_THR = 1e-2
colkw = 'loewe_12' ## type of synergy estimate
## container for the cell line & synergy statistics
cl_synstat_d = {}
## function to describe drug-response curves
def ic50_func(x,a):
    return 1/((x/a)+1)

for CL,data_d in cl_drg_data_d.items():
    DATA = pd.DataFrame(data_d).T
    DATA.index = pd.MultiIndex.from_tuples([k if isinstance(k,tuple) else (k,'dmso') for k in DATA.index])
    ## calculate the IC50s
    ## multiple dosages
    xic50_fits = {}
    for drg in reduced_dosage_d.keys():
        ## case 1 drug and drug_ld both exist in the dataset
        yvals1 = np.clip(DATA.loc[(drg,'dmso')],1e-6,1-1e-6).values
        yvals2 = np.clip(DATA.loc[(drg+'_ld','dmso')],1e-6,1-1e-6).values
        xvals1 = np.ones(yvals1.shape[0])*10
        xvals2 = np.ones(yvals2.shape[0])*10 * reduced_dosage_d[drg]/40.
        vrow_fit = np.r_[yvals1,yvals2]
        crow_fit = np.r_[xvals1,xvals2]
        if np.amin(vrow_fit)< 0.5 and 0.5 <np.amax(vrow_fit):
            guess = np.clip(np.median(crow_fit),0,200)
        elif np.amax(vrow_fit)< 0.5:
            guess = np.clip(np.amax(crow_fit),0,200)
        elif np.amin(vrow_fit)> 0.5:
            guess = np.clip(np.amin(crow_fit),0,200)
        aa,bb = curve_fit(ic50_func,crow_fit,vrow_fit,guess,bounds=(1e-3,1e3))
        xic50_fits[(drg,'ic50')]=aa[0]
        xic50_fits[(drg,'ic50_std')]=np.sqrt(bb[0][0])
    xic50_fits = pd.Series(xic50_fits)
    ## single dosages
    myic50s = {}
    for drg,row in DATA.xs('dmso',level=1).iterrows():
        if row.mean(axis=0)>.95:
            myic50s[(drg,'mu')]=2e2
            myic50s[(drg,'sig')]=0
        elif drg in xic50_fits.index.get_level_values(0):
            myic50s[(drg,'mu')] = xic50_fits.xs('ic50',level=1).loc[drg]
            myic50s[(drg,'sig')] = xic50_fits.xs('ic50_std',level=1).loc[drg]
        else:
            myic50s[(drg,'mu')]=10/(1/row.mean()-1)    
            myic50s[(drg,'sig')]=np.std([10/(1/(row.mean()+row.std()*np.random.randn())-1) for nn in range(100)])
    myic50_df = pd.Series(myic50s).unstack()
    SEL_SINGLES = DATA.xs('dmso',level=1)
    SEL_DOUBLES = DATA[DATA.index.get_level_values(1)!='dmso']
    drgp_syn_d = {}
    ## calculate the drug synergy
    for (drg1,drg2),row in SEL_DOUBLES.iterrows():
        drgp_syn_d[(drg1,drg2,'v_12')] = row.mean(axis=0)
        drgp_syn_d[(drg1,drg2,'v_12_std')] = row.std(axis=0)
        v_1 = SEL_SINGLES.loc[drg1].mean(axis=0)
        v_1_std = SEL_SINGLES.loc[drg1].std(axis=0)
        v_2 = SEL_SINGLES.loc[drg2].mean(axis=0)
        v_2_std = SEL_SINGLES.loc[drg2].std(axis=0)
        drgp_syn_d[(drg1,drg2,'v_1')] = v_1
        drgp_syn_d[(drg1,drg2,'v_1_std')] = v_1_std
        drgp_syn_d[(drg1,drg2,'v_2')] = v_2
        drgp_syn_d[(drg1,drg2,'v_2_std')] = v_2_std
        drgp_syn_d[(drg1,drg2,'bliss')] = v_1*v_2
        drgp_syn_d[(drg1,drg2,'bliss_std')] = np.sqrt(v_1_std**2+v_2_std**2)
        if drg1.endswith('_ld'):
            drg1p = drg1.split('_')[0]
            drg2p = drg2.split('_')[0]
            drgp_syn_d[(drg1,drg2,'loewe_12')] = 1/((10*reduced_dosage_d[drg1p]/40)/myic50_df.loc[drg1p,'mu']+(10*reduced_dosage_d[drg2p]/40)/myic50_df.loc[drg2p,'mu']+1)
        else:
            drgp_syn_d[(drg1,drg2,'loewe_12')] = 1/(10/myic50_df.loc[drg1,'mu']+10/myic50_df.loc[drg2,'mu']+1)
    synstat_df = pd.Series(drgp_syn_d).unstack()
    cl_synstat_d[CL]=synstat_df

# %%
## need to do fig. 5F (low-dosage analysis)
totaldosage=pd.Series(dict([((elt1+'_ld',elt2+'_ld'),reduced_dosage_d[elt1]+reduced_dosage_d[elt2]) for elt1,elt2 in ld_pairs]))
ldstat_d ={}
xTHR=1e-2 ## threshold to be included in "top" ranked group
tb_spc = 0.5
fig,ax_l = plt.subplots(1,4,dpi=180,figsize=(6.11,1.82),sharey=True)
colkw ='loewe_12'
clr_d = defaultdict(dict)
objval_clr_d = {'0.00':'C0','0.79':'C1','1.57':'C2'}
sym_d = {'Top':'^','Bottom':'v'}
num_d = {'0.00':0,'0.79':2,'1.57':4,'additive':0,'nonadditive':1}
for ar,CL in enumerate(['CH-157MN','GBM43','IOMM-LEE','LN-229']):
    print(CL)
    syn_d = defaultdict(dict)
    lbl_d = defaultdict(dict)
    pos_d = defaultdict(dict)
    for col in comb_pred.columns:
        synstat_df = cl_synstat_d[CL]
        high_thr = (synstat_df.loc[:,colkw]/synstat_df.v_12>1)[synstat_df.loc[:,colkw]>BP_THR].mean()
        low_thr = (synstat_df.loc[:,colkw]/synstat_df.v_12>1)[synstat_df.loc[:,colkw]<BP_THR].mean()
        sum_pred_ranks = comb_pred.loc[:,col].fillna(0).rank(pct=True,ascending=False)
        for kw in ['Top','Bottom']:
            if kw == 'Top':
                tot_sp = [elt for elt in ld_pairs if sum_pred_ranks.loc[elt]<xTHR]
            else:
                tot_sp = [elt for elt in ld_pairs if sum_pred_ranks.loc[elt]>=xTHR]

            sel_ld_keys = [tuple([val+'_ld' for val in elt]) for elt in tot_sp]
            exp_syn = ((synstat_df.loc[sel_ld_keys,'loewe_12']<BP_THR)*low_thr+(synstat_df.loc[sel_ld_keys,'loewe_12']>BP_THR)*high_thr)
            obs_syn = (synstat_df.loc[sel_ld_keys,'v_12']<synstat_df.loc[sel_ld_keys,'loewe_12']).mean()
            rnd_avg_l = []
            ## bootstrap the synergy values
            for dum in range(100):
                rnd_obs = synstat_df.loc[sel_ld_keys,'v_12']+np.random.randn(len(sel_ld_keys))*synstat_df.loc[sel_ld_keys,'v_12']
                rnd_avg = (rnd_obs<synstat_df.loc[sel_ld_keys,'loewe_12']).mean()
                rnd_avg_l.append(rnd_avg)
            rat_sig = np.std(rnd_avg_l)/exp_syn.mean() / np.sqrt(exp_syn.shape[0])
            rat_syn = obs_syn/exp_syn.mean()
            syn_d[col[1]][(kw,col[0])] = (rat_syn,rat_sig,exp_syn.shape[0])
            pos_ind = num_d[col[1]]+num_d[col[0]]
            pos_d[col[1]][(kw,col[0])] = (pos_ind)
            if kw=='Top':
                lbl_d[col[1]][(kw,col[0])] = ('%s %s' % (kw,col[0]))
    syn_d = dict(syn_d)
    pos_d = dict(pos_d)
    xticks=[]
    xticklabels=[]
    ## need to adjust to the new format of the syn_d dictionary 
    ## so that there is a legend with different symbols
    for objval,method_dat_d in syn_d.items():
        clr = objval_clr_d[objval]
        syn_dat_d = syn_d[objval]
        for (torb,aorna),(rats,raterrs,nums) in syn_dat_d.items():
            coll = ax_l[ar].errorbar(pos_d[objval][(torb,aorna)],rats,yerr=raterrs,fmt='%s%s' % (clr,sym_d[torb]),label=torb)
            if torb=='Top':
                xticks.append(pos_d[objval][(torb,aorna)] + tb_spc/2.)
                xticklabels.append(lbl_d[objval][(torb,aorna)])
            
        for ((meth1,tob1),syn1),((meth2,tob2),syn2) in combs(syn_dat_d.items(),2):
            mu1,sig1,obs1 = syn1
            mu2,sig2,obs2 = syn2
            rss2,rsp2 =ttest_ind_from_stats(mu1,sig1,obs1,mu2,sig2,obs2)
            ldstat_d[(CL,objval,meth1,tob1,meth2,tob2,'syn','rs_stat')]=rss2
            ldstat_d[(CL,objval,meth1,tob1,meth2,tob2,'syn','rs_pval')]=rsp2
    
    #ax_l[ar].set_title(CL,size=8)
    plt.setp(ax_l[ar].get_yticklabels(),size=6)
    ax_l[ar].axhline(1,ls='--',color='C7')

    ax_l[ar].set_xticks(xticks)
    ax_l[ar].set_xticklabels(xticklabels,size=6,rotation=90)
    plt.setp(ax_l[ar].get_xticklabels(),size=6,rotation=90)
ax_l[0].set_ylim(0.95,1.75)
plt.setp(ax_l[0].get_yticklabels(),size=6)
#ax_l[0].axhline(1,ls='--')
ax_l[0].set_ylabel('Synergy ratio',size=8)
ax_l[-1].legend(frameon=False,prop={'size':6})
fig.savefig(osp.join(OUTPUT_DIR,'low_dosage_comparison.svg')) ## this is for ALL METHODS
pd.Series(ldstat_d).unstack([-2,-1]).to_excel(osp.join(OUTPUT_DIR,'low_dosage_statistics.xlsx'))
# Out:
# CH-157MN
# GBM43
# IOMM-LEE
# LN-229

# %% [markdown]
# #### Fig. 5F

# %%
## need to do fig. 5F (low-dosage analysis)
totaldosage=pd.Series(dict([((elt1+'_ld',elt2+'_ld'),reduced_dosage_d[elt1]+reduced_dosage_d[elt2]) for elt1,elt2 in ld_pairs]))
ldstat_d ={}
xTHR=1e-2 ## threshold to be included in "top" ranked group
tb_spc = 0.5

colkw ='loewe_12'
clr_d = defaultdict(dict)
objval_clr_d = {'0.79':'C1'}

add_trend = [auc_info_d[(CL,'0.79','additive')] for CL in kw_df.iloc[:,0].unique()]
add_pos = [2*CL_num_d[CL] for CL in kw_df.iloc[:,0].unique()]
nadd_trend = [auc_info_d[(CL,'0.79','nonadditive')] for CL in kw_df.iloc[:,0].unique()]
nadd_pos = [2*CL_num_d[CL]+1 for CL in kw_df.iloc[:,0].unique()]

num_d = {'CH-157MN':0,'GBM43':2,'IOMM-LEE':4,'LN-229':6,'additive':0,'nonadditive':1}

lbl_d = defaultdict(dict)
syn_d = defaultdict(dict)
pos_d = defaultdict(dict)


for ar,CL in enumerate(['CH-157MN','GBM43','IOMM-LEE','LN-229']):
    print(CL)
    synstat_df = cl_synstat_d[CL]
    high_thr = (synstat_df.loc[:,colkw]/synstat_df.v_12>1)[synstat_df.loc[:,colkw]>BP_THR].mean()
    low_thr = (synstat_df.loc[:,colkw]/synstat_df.v_12>1)[synstat_df.loc[:,colkw]<BP_THR].mean()
    for col in comb_pred.columns:
        if col[1]!='0.79':
            continue
        sum_pred_ranks = comb_pred.loc[:,col].fillna(0).rank(pct=True,ascending=False)
        for kw in ['Top','Bottom']:
            if kw == 'Top':
                tot_sp = [elt for elt in ld_pairs if sum_pred_ranks.loc[elt]<xTHR]
            else:
                tot_sp = [elt for elt in ld_pairs if sum_pred_ranks.loc[elt]>=xTHR]

            sel_ld_keys = [tuple([val+'_ld' for val in elt]) for elt in tot_sp]
            exp_syn = ((synstat_df.loc[sel_ld_keys,colkw]<BP_THR)*low_thr+(synstat_df.loc[sel_ld_keys,colkw]>BP_THR)*high_thr)
            obs_syn = (synstat_df.loc[sel_ld_keys,'v_12']<synstat_df.loc[sel_ld_keys,colkw]).mean()
            rnd_avg_l = []
            ## bootstrap the synergy values
            for dum in range(100):
                rnd_obs = synstat_df.loc[sel_ld_keys,'v_12']+np.random.randn(len(sel_ld_keys))*synstat_df.loc[sel_ld_keys,'v_12']
                rnd_avg = (rnd_obs<synstat_df.loc[sel_ld_keys,colkw]).mean()
                rnd_avg_l.append(rnd_avg)
            rat_sig = np.std(rnd_avg_l)/exp_syn.mean() / np.sqrt(exp_syn.shape[0])
            rat_syn = obs_syn/exp_syn.mean()
            syn_d[(kw,col[0])][CL] = (rat_syn,rat_sig,exp_syn.shape[0])
            pos_ind = num_d[CL]+num_d[col[0]]
            pos_d[(kw,col[0])][CL] = (pos_ind)
            lbl_d[(kw,col[0])][CL] = ('%s %s' % (kw,col[0]))
syn_d = dict(syn_d)
pos_d = dict(pos_d)
lbl_d = dict(lbl_d)
# Out:
# CH-157MN
# GBM43
# IOMM-LEE
# LN-229

# %%
symbol_d = {'Top':'^','Bottom':'v'}

method_clr_d = {'additive':'C3','nonadditive':'C4'}

#kk_num_d = {'Additive':0,'Nonadditive':1}
auc_tstat_d = {}
fig,ax = plt.subplots(1,1,dpi=180,figsize=(3.5,1.5),sharey=True)
ax.set_ylabel('Synergy ratio',size=8)
plt.setp(ax2.get_yticklabels(),size=6)

## need to adjust to the new format of the syn_d dictionary 
## so that there is a legend with different symbols
for (torb,method),method_dat_d in syn_d.items():
    method_dat_df = pd.DataFrame(method_dat_d,index=['syn_ratio','syn_ratio_err','num'])
    pos_ser = pd.Series(pos_d[(torb,method)])
    clr = method_clr_d[method]
    coll = ax.errorbar(pos_ser.loc[method_dat_df.columns],
                       method_dat_df.loc['syn_ratio'],
                       yerr=method_dat_df.loc['syn_ratio_err'],
                       fmt='%s%s' % (clr,symbol_d[torb]),label=f'{torb} {method}')
        
    for ((tob1,meth1),syn1),((tob2,meth2),syn2) in combs(syn_dat_d.items(),2):
        syn1_df = pd.DataFrame(syn1,index=['syn_ratio','syn_ratio_err','num'])
        syn2_df = pd.DataFrame(syn2,index=['syn_ratio','syn_ratio_err','num'])
        rss2,rsp2 =ttest_ind_from_stats(syn1_df.loc['syn_ratio'],syn1_df.loc['syn_ratio_err'],syn1_df.loc['num'],
                                        syn2_df.loc['syn_ratio'],syn2_df.loc['syn_ratio_err'],syn2_df.loc['num'])
        ldstat_d[(CL,meth1,tob1,meth2,tob2,'syn','rs_stat')]=rss2
        ldstat_d[(CL,meth1,tob1,meth2,tob2,'syn','rs_pval')]=rsp2


ax.set_ylabel('Synergy ratio',size=8)
ax.axhline(1,ls='--',color='C7')
ax.legend(frameon=False,prop={'size':6},ncol=2)
ax.axvspan(1.5,3.5,color='C7',alpha=0.1)
ax.axvspan(5.5,7.5,color='C7',alpha=0.1)
xtls = ['CH-157MN','GBM43','IOMM-LEE','LN-229']
xts = 0.5+2*np.arange(len(xtls))
ax.set_xticks(xts)
ax.set_xticklabels(xtls,size=6)
plt.setp(ax.get_yticklabels(),size=6)
ax.set_xlim(-0.5,7.5)
fig.savefig(osp.join(OUTPUT_DIR,'fig5f_low_dosage_comparison_singlemethod.svg'))
pd.Series(ldstat_d).unstack([-2,-1]).to_excel(osp.join(OUTPUT_DIR,'low_dosage_statistics_singlemethod.xlsx'))

# %% [markdown]
# ### Fig. S1

# %% [markdown]
# #### Fig. S1AB

# %%
auc_syninfo_d = {}
NRREP=100
for CL,synstat_df in cl_synstat_d.items():
    VTHR=(synstat_df.loc[:,'v_12']-synstat_df.loc[:,colkw]).median()
    for fnbase in fnbase_l[:1]:
        lbl = 'lodo' if fnbase.startswith('lodo') else 'ctpair'
        for objval in ['0.00','0.79','1.57']:
            if CL=='LN-229' and objval=='0.79':
                fig,ax = plt.subplots(2,1,dpi=180,figsize=(3,4))
            fpr_l = []
            tpr_l = []
            thrl_l = []
            IS_l = []
            var_pred_l = []
            for kk in range(2):
                bsubstr,predstr = ('nonadd','nonadditive') if kk!=0 else ('linear','additive')
                fntot = INPUT_DIR + '/' + fnbase
                xdiffs = pd.read_pickle(fntot % bsubstr)
                cmb_diffs = (xdiffs.xs(objval,level=2)).copy()
                pred = comb_pred.loc[:,(predstr,objval)]
                #pred = pred[~pred.isna()]
                cmb_diffs.index = alphasrt_multiindex(cmb_diffs.index)
                IS = pred[~pred.isna()].index.intersection(synstat_df.index)
                IS_l.append(IS)
                var_pred_l.append((cmb_diffs,pred,bsubstr))
            common = IS_l[0].union(IS_l[1])
            common_stats = {}
            common_stats['mean']=(synstat_df.loc[common,'v_12']-synstat_df.loc[common,'loewe_12'])
            common_stats['std']=synstat_df.loc[common,'v_12_std']
            common_stats = pd.DataFrame(common_stats)
            rnd_vals_l = []
            auc_dd = defaultdict(list)
            for kk,(cmb_diffs,pred,bsubstr) in enumerate(var_pred_l):
                fact= 6 if fnbase.startswith('lodo') and kk==0 else 1
                duma = pred.loc[common].sort_values(ascending=False) #.fillna(0)
                wtrank = (duma/duma.sum()).cumsum()
                wtrank_l = []
                for elt in common.difference(cmb_diffs.index):
                    cmb_diffs.loc[elt,'mu'] = np.nan
                    cmb_diffs.loc[elt,'sig'] = np.nan
                for nn in range(NRREP):
                    rnd_val_d = {}
                    dum = pred.loc[common]+fact*cmb_diffs.loc[common,'sig']*np.random.randn(common.shape[0])
                    rnd_wtrank = (dum/dum.sum()).sort_values(ascending=False).cumsum().loc[common]
                    if kk==0:
                        rnd_vals = common_stats.loc[common,'mean']+np.random.randn(common_stats.shape[0])*common_stats.loc[common,'std']
                        rnd_vals_l.append(rnd_vals)
                    else:
                        rnd_vals = rnd_vals_l[nn]
                    SEL = ~rnd_wtrank.loc[common].isna()
                    rfpr,rtpr,rthrl = roc_curve(common_stats[SEL].loc[:,'mean']<VTHR,1-rnd_wtrank[SEL])
                    auc_dd[bsubstr].append(auc(rfpr,rtpr))
                    wtrank_l.append(rnd_wtrank)
                    
                    ## need to calculate the AUC distribution here
                wtrank_sig = pd.concat(wtrank_l,axis=1).std(axis=1)/10.
                fpr,tpr,thrl = roc_curve(common_stats[~wtrank.loc[common].isna()].loc[:,'mean']<VTHR,1-wtrank.loc[common][~wtrank.isna()])
                fpr_l.append(fpr)
                tpr_l.append(tpr)
                thrl_l.append(thrl)
                act_auc = auc(fpr,tpr)
                auc_dd[bsubstr].append(act_auc)
                if CL=='LN-229' and objval=='0.79':
                    ax[0].errorbar(wtrank.loc[common],common_stats.loc[:,'mean'],
                                 xerr=wtrank_sig.loc[common],yerr=common_stats.loc[:,'std'],fmt='C%d.' % (kk+3),alpha=0.5)
                    ax[1].plot(fpr,tpr,label='%s : %.02f' % (bsubstr,act_auc),color='C%d' % (kk+3))
            auc_d = dict(auc_dd)
            for kk,vv in auc_d.items():
                auc_syninfo_d[(CL,objval,kk)]=vv
            if CL=='LN-229' and objval=='0.79':
                #ax[0].set_yscale('log')
                ax[0].set_ylabel('Synergy',size=8)
                ax[0].set_xlabel('Weighted rank',size=8)
                ax[0].axhline(VTHR,ls='--',color='C7')
                ind1 = 20
                ax[0].axvline((1-thrl_l[1][ind1]),ls='-',color='C7')
                ax[0].set_ylim(-0.25,0.25)
                ax[1].set_ylabel('TPR',size=8)
                ax[1].set_xlabel('FPR',size=8)
                ax[1].plot(fpr_l[1][ind1:ind1+1],tpr_l[1][ind1:ind1+1],color='C4' ,marker=(5,1,0))
                ind0 = np.argmin(np.abs((1-np.asarray(thrl_l[0]))-(1-thrl_l[1][ind1])))
                ax[1].plot(fpr_l[0][ind0:ind0+1],tpr_l[0][ind0:ind0+1],color='C3',marker=(5,1,0))                 
                ax[1].legend(title='AUC',frameon=False,prop={'size':6})
                ax[1].plot(np.linspace(0,1),np.linspace(0,1),ls='--',color='C7')
                plt.setp(ax[0].get_xticklabels(),size=6)
                plt.setp(ax[0].get_yticklabels(),size=6)
                plt.setp(ax[1].get_xticklabels(),size=6)
                plt.setp(ax[1].get_yticklabels(),size=6)
                fig.savefig(osp.join(OUTPUT_DIR,'figS1a_example_LN-229_0.79_synergy_trend_col.svg'))

# %% [markdown]
# #### Fig. S1C

# %%
kw_df = pd.DataFrame(auc_syninfo_d.keys())
fig2,ax2a = plt.subplots(2,2,dpi=180,sharey=True,sharex=True,figsize=(6,4))
objval_clr_d = {'0.00':'C0','0.79':'C1','1.57':'C2'}
objval_str_d = {'0.00':'Behavior','0.79':'Combined','1.57':'Growth'}
objval_num_d = {'0.00':0,'0.79':1,'1.57':2}
kk_num_d = {'linear':0,'nonadd':1}
auc_syntstat_d = {}
for ii,CL in enumerate(kw_df.iloc[:,0].unique()):    
    ROW,COL = (ii//2),(ii%2)
    ax2 = ax2a[ROW,COL]
    ax2.set_title(CL,size=8)
    if COL ==0:
        ax2.set_ylabel('Synergy AUC',size=8)
        ax2.set_ylim(0,1)
        plt.setp(ax2.get_yticklabels(),size=6)
    clr_dat_d = defaultdict(list)
    for (CLz,objval,kk) in kw_df[kw_df.iloc[:,0]==CL].values:
        clr = objval_clr_d[objval]
        pos=2*objval_num_d[objval]+kk_num_d[kk]
        clr_dat_d[clr].append((auc_syninfo_d[(CL,objval,kk)],pos,kk))
    for (CLx,objval1,kk1),(CLy,objval2,kk2) in combs(kw_df[kw_df.iloc[:,0]==CL].values,2):
        auc_l1 = auc_syninfo_d[(CL,objval1,kk1)]
        auc_l2 = auc_syninfo_d[(CL,objval2,kk2)]
        tstat,pval = ranksums(auc_l1,auc_l2)
        auc_syntstat_d[(CL,objval1,kk1,objval2,kk2,'rstat')]=tstat
        auc_syntstat_d[(CL,objval1,kk1,objval2,kk2,'pval')]=pval        
    clr_dat_d = dict(clr_dat_d)
    clr_l = []
    box_l = []
    for clr,dat in clr_dat_d.items():
        data_l,pos_l,lbl_l = zip(*dat)
        lbl_l = ['' for elt in lbl_l] if ROW==0 else lbl_l
        box = ax2.boxplot(data_l,positions=pos_l,labels=lbl_l,widths=0.6,patch_artist=True,
                         notch=False,sym='%s.' % clr,boxprops={'color':clr,'alpha':0.5},
                         whiskerprops={'color':'k'}, capprops={'color':'k'},
                         medianprops={'color':'C3'},flierprops={'alpha':0.5,'markeredgecolor':None})
        box_l.append(box)
        clr_l.append(clr)
    for clr,bplot in zip(clr_l,box_l):
        sclr = [box.set_color(clr) for box in bplot['boxes']]
        sal = [box.set_alpha(0.5) for box in bplot['boxes']]
    ax2.axhline(0.5,ls='--',color='C7')
    if ROW==1:
        plt.setp(ax2.get_xticklabels(),rotation=90,size=6)
fig2.savefig(osp.join(OUTPUT_DIR,'ranked_auc_synergy.svg'))
auc_syntstat_ser=pd.Series(auc_syntstat_d)
auc_syntstat_ser = auc_syntstat_ser.unstack(0)
auc_syntstat_ser.to_excel(osp.join(OUTPUT_DIR,'ranked_synergy_auc_tstats.xlsx'))

# %%
kw_df = pd.DataFrame(auc_syninfo_d.keys())
fig,ax = plt.subplots(1,1,dpi=180,figsize=(3.5,1.5))
method_clr_d = {'additive':'C3','nonadditive':'C4'}
objval_str_d = {'0.00':'Behavior','0.79':'Combined','1.57':'Growth'}
num_d = {'CH-157MN':0,'GBM43':2,'IOMM-LEE':4,'LN-229':6,'additive':0,'nonadditive':1}
mlbl_d = {'linear':'additive','nonadd':'nonadditive'}
ax.set_ylabel('Synergy AUC',size=8)
ax.set_ylim(0,1)
plt.setp(ax.get_yticklabels(),size=6)

auc_syntstat_d = {}
method_dat_d = defaultdict(dict)
for ii,CL in enumerate(kw_df.iloc[:,0].unique()):    
    for (CLz,objval,kk) in kw_df[(kw_df.iloc[:,0]==CL)&(kw_df.iloc[:,1]=='0.79')].values:
        method_dat_d[mlbl_d[kk]][CL]=(auc_syninfo_d[(CL,objval,kk)],num_d[CL]+num_d[mlbl_d[kk]])
    for (CLx,objval1,kk1),(CLy,objval2,kk2) in combs(kw_df[(kw_df.iloc[:,0]==CL)&(kw_df.iloc[:,1]=='0.79')].values,2):
        auc_l1 = auc_syninfo_d[(CL,objval1,kk1)]
        auc_l2 = auc_syninfo_d[(CL,objval2,kk2)]
        tstat,pval = ranksums(auc_l1,auc_l2)
        auc_syntstat_d[(CL,objval1,kk1,objval2,kk2,'rstat')]=tstat
        auc_syntstat_d[(CL,objval1,kk1,objval2,kk2,'pval')]=pval        
method_dat_d = dict(method_dat_d)
for method,dat in method_dat_d.items():
    data_l = [elt[0] for elt in dat.values()]
    pos_l = [elt[1] for elt in dat.values()]
    clr = method_clr_d[method]
    box = ax.boxplot(data_l,positions=pos_l,widths=0.6,patch_artist=True,
                        notch=False,sym='%s.' % clr,boxprops={'edgecolor':clr,'facecolor':clr},
                        whiskerprops={'color':clr}, capprops={'color':clr},
                        medianprops={'color':'C1'},flierprops={'alpha':0.5,'markeredgecolor':'none','markerfacecolor':clr})
    box_l.append(box)
    clr_l.append(clr)



ax.axvspan(1.5,3.5,color='C7',alpha=0.1)
ax.axvspan(5.5,7.5,color='C7',alpha=0.1)
ax.axhline(0.5,ls='--',color='C7')
xticks = [0.5,2.5,4.5,6.5]
xticklabels = ['CH-157MN','GBM43','IOMM-LEE','LN-229']
ax.set_xticks(xticks)
ax.set_xlim(-0.5,7.5)
ax.set_xticklabels(xticklabels,size=6)


fig.savefig(osp.join(OUTPUT_DIR,'figS1c_ranked_auc_synergy_singlemethod.svg'))
auc_syntstat_ser=pd.Series(auc_syntstat_d)
auc_syntstat_ser = auc_syntstat_ser.unstack(0)
auc_syntstat_ser.to_excel(osp.join(OUTPUT_DIR,'ranked_synergy_auc_tstats_singlemethod.xlsx'))

# %% [markdown]
# ### Fig. S1D

# %%
fig,ax_l = plt.subplots(1,4,dpi=180,figsize=(6.11,1.82),sharey=True)
colkw ='loewe_12'
clr_d = defaultdict(dict)
objval_clr_d = {'0.00':'C0','0.79':'C1','1.57':'C2'}
torb_alpha_d = {'Top':0.9,'Bottom':0.5}
num_d = {'0.00':0,'0.79':2,'1.57':4,'additive':0,'nonadditive':1}
NP = 1000
tb_spc = 0.5
for ar,CL in enumerate(['CH-157MN','GBM43','IOMM-LEE','LN-229']):
    print(CL)
    dat_d = defaultdict(dict)
    #tot_l = [5,22.5,40]
    lbl_d = defaultdict(dict)
    pos_d = defaultdict(dict)
    pos_ind = 0
    for col in comb_pred.columns:
        data_d = cl_drg_data_d[CL]
        DATA = pd.DataFrame(data_d).T
        DATA.index = pd.MultiIndex.from_tuples([k if isinstance(k,tuple) else (k,'dmso') for k in DATA.index])
        sum_pred_ranks = comb_pred.loc[:,col].fillna(0).rank(pct=True,ascending=False)
        for kw in ['Top','Bottom']:
            if kw == 'Top':
                tot_sp = [elt for elt in ld_pairs if sum_pred_ranks.loc[elt]<BP_THR]
            else:
                tot_sp = [elt for elt in ld_pairs if sum_pred_ranks.loc[elt]>=BP_THR]

            sel_ld_keys = [tuple([val+'_ld' for val in elt]) for elt in tot_sp]
            rnd_avg_l = []
            if NP>len(sel_ld_keys):
                NP=len(sel_ld_keys)
            dat_d[col[1]][(kw,col[0])] = (1-DATA.loc[sel_ld_keys].mean(axis=1))/totaldosage.loc[sel_ld_keys]
            pos_ind = num_d[col[1]]+num_d[col[0]]
            pos_d[col[1]][(kw,col[0])] = pos_ind
            if kw=='Top':
                lbl_d[col[1]][(kw,col[0])] = ('%s' % (col[0]))
    dat_d = dict(dat_d)
    pos_d = dict(pos_d)
    lbl_d = dict(lbl_d)
    xticks=[]
    xticklabels=[]
    for objval,method_dat_d in dat_d.items():
        clr = objval_clr_d[objval]
        for (torb,aorna),data_list in method_dat_d.items():
            if torb=='Bottom':
                xpos = pos_d[objval][(torb,aorna)] + tb_spc
            else:
                xpos = pos_d[objval][(torb,aorna)]
            if torb=='Top':
                xticks.append(pos_d[objval][(torb,aorna)] + tb_spc/2.)
                xticklabels.append(lbl_d[objval][(torb,aorna)])
            boxes0 = ax_l[ar].boxplot(data_list,labels=[torb],widths=[0.3],
                                      sym='%s.' % clr, positions=[xpos],
                                      patch_artist=True, notch=False,
                                      boxprops={'color':clr,'alpha':torb_alpha_d[torb]},
                                      whiskerprops={'color':'k'},capprops={'color':'k'},medianprops={'color':'C3'},
                                      flierprops={'alpha':0.5,'markeredgecolor':None})
            sclr = [boxes0['boxes'][xx].set_color(clr) for xx in range(len(boxes0['boxes']))]
            sal = [boxes0['boxes'][xx].set_alpha(torb_alpha_d[torb]) for xx in range(len(boxes0['boxes']))]
    ax_l[ar].set_title(CL,size=8)
    ax_l[ar].set_xticks(xticks)
    ax_l[ar].set_xticklabels(xticklabels,size=6,rotation=90)
    plt.setp(ax_l[ar].get_xticklabels(),size=6,rotation=90)
ax_l[0].set_ylabel(r'Viability reduction per $\mu$M',size=8)
plt.setp(ax_l[0].get_yticklabels(),size=6)
ax_l[0].set_yscale('log')

fig.savefig(osp.join(OUTPUT_DIR,'low_dosage_viability.svg'))
# Out:
# CH-157MN
# GBM43
# IOMM-LEE
# LN-229

# %%
## single method
fig,ax = plt.subplots(1,1,dpi=180,figsize=(3.5,1.5))
colkw ='loewe_12'

method_clr_d = {'additive':'C3','nonadditive':'C4'}
objval_str_d = {'0.00':'Behavior','0.79':'Combined','1.57':'Growth'}
num_d = {'CH-157MN':0,'GBM43':2,'IOMM-LEE':4,'LN-229':6,'additive':0,'nonadditive':1,'Top':0.5,'Bottom':0}
mlbl_d = {'linear':'additive','nonadd':'nonadditive'}

method_dat_d = defaultdict(dict)

torb_alpha_d = {'Top':0.9,'Bottom':0.5}
NP = 1000
tb_spc = 0.5
for ar,CL in enumerate(['CH-157MN','GBM43','IOMM-LEE','LN-229']):
    print(CL)
    pos_ind = 0
    for col in comb_pred.columns:
        if col[1]=='0.79':
            data_d = cl_drg_data_d[CL]
            DATA = pd.DataFrame(data_d).T
            DATA.index = pd.MultiIndex.from_tuples([k if isinstance(k,tuple) else (k,'dmso') for k in DATA.index])
            sum_pred_ranks = comb_pred.loc[:,col].fillna(0).rank(pct=True,ascending=False)
            for kw in ['Top','Bottom']:
                if kw == 'Top':
                    tot_sp = [elt for elt in ld_pairs if sum_pred_ranks.loc[elt]<BP_THR]
                else:
                    tot_sp = [elt for elt in ld_pairs if sum_pred_ranks.loc[elt]>=BP_THR]

                sel_ld_keys = [tuple([val+'_ld' for val in elt]) for elt in tot_sp]
                rnd_avg_l = []
                if NP>len(sel_ld_keys):
                    NP=len(sel_ld_keys)
                viability_reduction_per_um = (1-DATA.loc[sel_ld_keys].mean(axis=1))/totaldosage.loc[sel_ld_keys]
                pos_ind = num_d[CL]+num_d[kw]+num_d[col[0]]
                method_dat_d[(col[0],kw)][(CL)] = (viability_reduction_per_um,pos_ind)
    xticks=[]
    xticklabels=[]

for (method,torb),dat_d in method_dat_d.items():
    data_l = [elt[0] for elt in dat_d.values()]
    pos_l = [elt[1] for elt in dat_d.values()]
    clr = method_clr_d[method]
    aval = torb_alpha_d[torb]
    box = ax.boxplot(data_l,positions=pos_l,widths=0.3,patch_artist=True,
                     notch=False,sym='%s.' % clr,boxprops={'edgecolor':clr,'facecolor':clr,'alpha':aval},
                     whiskerprops={'color':clr,'alpha':aval}, capprops={'color':clr,'alpha':aval},
                     medianprops={'color':'C1'},
                     flierprops={'alpha':0.5,'markeredgecolor':'none','markerfacecolor':clr,'alpha':aval})

ax.set_ylabel(r'Viability reduction per $\mu$M',size=8)
plt.setp(ax.get_yticklabels(),size=6)
ax.set_yscale('log')
ax.axvspan(1.75,3.75,color='C7',alpha=0.1)
ax.axvspan(5.75,7.75,color='C7',alpha=0.1)
#ax.axhline(0.5,ls='--',color='C7')
xticks = [0.75,2.75,4.75,6.75]
xticklabels = ['CH-157MN','GBM43','IOMM-LEE','LN-229']
ax.set_xticks(xticks)
ax.set_xlim(-0.25,7.75)
ax.set_xticklabels(xticklabels,size=6)

fig.savefig(osp.join(OUTPUT_DIR,'low_dosage_viability_singlemethod.svg'))
# Out:
# CH-157MN
# GBM43
# IOMM-LEE
# LN-229

# %%
fig,ax = plt.subplots(1,1,dpi=180,figsize=(3.5,1.5))
all_top_nonadd = [val for elt in method_dat_d[('nonadditive', 'Top')].values() for val in elt[0].values]
all_top_add = [val for elt in method_dat_d[('additive', 'Top')].values() for val in elt[0].values]
ax.hist(all_top_nonadd,bins=np.linspace(0+1e-3,0.20+1e-3,101),color='C4',histtype='step')
ax.hist(all_top_add,bins=np.linspace(0,0.20,101),color='C3',histtype='step')
ax.set_xticks(np.linspace(0,0.2,6))
plt.setp(ax.get_xticklabels(),size=6)
plt.setp(ax.get_yticklabels(),size=6)
ax.set_xlabel(r'Viability reduction per $\mu$M',size=8)
ax.set_ylabel('Count',size=8)
fig.savefig(f'{OUTPUT_DIR}/figS1D_singlemethod_viability_per_uM.svg')

# %% [markdown]
# ### Analysis of drug pairs exclusive to each method

# %% [markdown]
# #### Statistics associated with the exclusive drugs

# %%
## code to calculate the synergy statistics

## first, update the "unselected" group to include drugs selected by alternative objective functions
rnd_kws = lbl_kw_d['random']
add2unselected = ['Behavior additive (blue)', 'Behavior average (blue)', 'Behavior nonadditive (blue)','Growth additive (green)',
 'Growth average (green)', 'Growth nonadditive (green)']
new_unsel_inds = [tuple(elt) for elt in test_grps[test_grps.group.isin(add2unselected)].loc[:,['drug1_name','drug2_name']].values]
lbl_kw_d['random'] =rnd_kws+new_unsel_inds


op_d = {}
for CL,synstat_df in cl_synstat_d.items():
    ## synergy rates above and below the viability thresholds
    high_thr = (synstat_df.loc[:,colkw]/synstat_df.v_12>1)[synstat_df.loc[:,colkw]>BP_THR].mean()
    low_thr = (synstat_df.loc[:,colkw]/synstat_df.v_12>1)[synstat_df.loc[:,colkw]<BP_THR].mean()
    print(CL,high_thr,low_thr)
    sel_ld_d = {}
    sel_ncld_d = {}
    unsel_ld_d = {}    
    for d1,d2 in ld_pairs:
        d1p = d1+'_ld'
        d2p = d2+'_ld'
        if (d1,d2) in sel_inds_d.keys():
            sel_ld_d[('observed',d1,d2)] = (synstat_df.loc[(d1p,d2p),'v_12'] < synstat_df.loc[(d1p,d2p),colkw])
            sel_ld_d[('expected',d1,d2)] = low_thr if synstat_df.loc[(d1p,d2p),colkw]<BP_THR else high_thr
        elif (d2,d1) in sel_inds_d.keys():
            sel_ld_d[('observed',d1,d2)] = (synstat_df.loc[(d1p,d2p),'v_12'] < synstat_df.loc[(d1p,d2p),colkw])
            sel_ld_d[('expected',d1,d2)] = low_thr if synstat_df.loc[(d1p,d2p),colkw]<BP_THR else high_thr
        else:
            unsel_ld_d[('observed',d1,d2)] = (synstat_df.loc[(d1p,d2p),'v_12'] < synstat_df.loc[(d1p,d2p),colkw])
            unsel_ld_d[('expected',d1,d2)] = low_thr if synstat_df.loc[(d1p,d2p),colkw]<BP_THR else high_thr
    ## estimate the synergy ratio statistics (low dosage)
    for lbl,sel_d in zip(['top_ld','unsel_ld'],[sel_ld_d,unsel_ld_d]):
        sel_df = pd.Series(sel_d).unstack(level=0).astype(float)
        newindex = [(e1+'_ld',e2+'_ld') for e1,e2 in sel_df.index]
        for knd,val in sel_df.mean().items():
            op_d[(CL,lbl,knd)]=val
        op_d[(CL,lbl,'ratio')]=op_d[(CL,lbl,'observed')]/op_d[(CL,lbl,'expected')]
        obs_l = []
        exp_l = []
        rat_l = []
        ## bootstrap the synergy ratio (low dosage)
        for mm in range(100):
            rac = synstat_df.loc[newindex,'v_12']+synstat_df.loc[newindex,'v_12_std']*np.random.randn(sel_df.shape[0])
            rloewe_d = {}
            for (kk0,kk1) in sel_df.index:
                rloewe_d[(kk0+'_ld',kk1+'_ld')] = 1/(10/(myic50_df.loc[kk0,'mu']+myic50_df.loc[kk0,'sig']*np.random.randn())+
                                        10/(myic50_df.loc[kk1,'mu']+myic50_df.loc[kk1,'sig']*np.random.randn())+1)            
            rloewe = pd.Series(rloewe_d)
            rexp = ((rloewe<BP_THR)*low_thr+(rloewe>BP_THR)*high_thr)
            robs =(rac<rloewe).mean()
            obs_l.append(robs)
            exp_l.append(rexp.mean())
            rat_l.append(robs/rexp.mean())
        op_d[(CL,lbl,'observed_std')]=np.std(obs_l)
        op_d[(CL,lbl,'expected_std')]=np.std(exp_l)
        op_d[(CL,lbl,'ratio_std')]=np.std(rat_l)
        
    ## estimate the synergy ratio statistics
    for lbl,kk_l in lbl_kw_d.items():
        act_syn = (synstat_df.loc[kk_l,'v_12'] < synstat_df.loc[kk_l,colkw]).mean()
        bl_syn = (synstat_df.loc[kk_l,colkw]<BP_THR)*low_thr+(synstat_df.loc[kk_l,colkw]>BP_THR)*high_thr
        op_d[(CL,lbl,'observed')]=act_syn
        op_d[(CL,lbl,'expected')]=bl_syn.mean()
        op_d[(CL,lbl,'ratio')]=act_syn/bl_syn.mean()
        obs_l = []
        exp_l = []
        rat_l = []
        ## bootstrap the synergy ratio
        for mm in range(100):
            rac = synstat_df.loc[kk_l,'v_12']+synstat_df.loc[kk_l,'v_12_std']*np.random.randn(len(kk_l))
            rloewe_d = {}
            for (kk0,kk1) in kk_l:
                rloewe_d[(kk0,kk1)] = 1/(10/(myic50_df.loc[kk0,'mu']+myic50_df.loc[kk0,'sig']*np.random.randn())+
                                        10/(myic50_df.loc[kk1,'mu']+myic50_df.loc[kk1,'sig']*np.random.randn())+1)            
            rloewe = pd.Series(rloewe_d)
            rexp = ((rloewe<BP_THR)*low_thr+(rloewe>BP_THR)*high_thr)
            robs =(rac<rloewe).mean()
            obs_l.append(robs)
            exp_l.append(rexp.mean())
            rat_l.append(robs/rexp.mean())
        op_d[(CL,lbl,'observed_std')]=np.std(obs_l)
        op_d[(CL,lbl,'expected_std')]=np.std(exp_l)
        op_d[(CL,lbl,'ratio_std')]=np.std(rat_l)

gross_synergy_stats = pd.Series(op_d).unstack()
gross_synergy_stats.to_excel(osp.join(OUTPUT_DIR,'gross_synergy_stats.xlsx'))
# Out:
# CH-157MN 0.5353846153846153 0.07692307692307693
# GBM43 0.5225225225225225 0.14457831325301204
# IOMM-LEE 0.5498489425981873 0.11764705882352941
# LN-229 0.5342105263157895 0.1388888888888889

# %%
comp_kwp_d = {
    'nonadd_v_add':(('nonadditive', 'comb', 'top'),('additive', 'comb', 'top')),
    'bhv_nonadd_v_add':(('nonadditive', '0.00', 'top'),('additive', '0.00', 'top')),
    'comb_nonadd_v_add':(('nonadditive', '0.79', 'top'),('additive', '0.79', 'top')),
    'growth_nonadd_v_add':(('nonadditive', '1.57', 'top'),('additive', '1.57', 'top')),
    'growth_tvb_bhv':(('comb', '0.00', 'top'),('comb', '0.79', 'top'),('comb', '1.57', 'top'),('comb', '1.57', 'bot')),
    'add_bhv':(('additive', '0.00', 'top'),('additive', '0.79', 'top'),('additive', '1.57', 'top')),
    'nonadd_bhv':(('nonadditive', '0.00', 'top'),('nonadditive', '0.79', 'top'),('nonadditive', '1.57', 'top'))
}

comp_labels_d = {
    'nonadd_v_add':(('Nonadditive','C7'),('Additive', 'C7')),
    'bhv_nonadd_v_add':(('Nonadditive','C0'),('Additive', 'C0')),
    'comb_nonadd_v_add':(('Nonadditive', 'C1'),('Additive', 'C1')),
    'growth_nonadd_v_add':(('Nonadditive', 'C2'),('Additive', 'C2')),
    'growth_tvb_bhv':(('Behavior','C0'),('Combined', 'C1'),('Growth', 'C2'),('Non-growth','C3')),
    'nonadd_bhv':(('Behavior','C0'),('Combined', 'C1'),('Growth', 'C2')),
    'add_bhv':(('Behavior','C0'),('Combined', 'C1'),('Growth', 'C2')),
}

# %%
plt.rcParams['svg.fonttype']='none'
stats_d = {}
fig,ax_l = plt.subplots(4,2,dpi=180,figsize=(6,6),sharex=True)
axi=0
for CL,drg_data_d in cl_drg_data_d.items():
    ## compare the drug viability data
    print(CL)
    ax=ax_l[axi,0]
    axi +=1
    DATA = pd.DataFrame(drg_data_d).T
    DATA.index = pd.MultiIndex.from_tuples([k if isinstance(k,tuple) else (k,'dmso') for k in DATA.index])
    pos_ind = 0
    clr_data_d = defaultdict(list)
    for comp_nm, inds_l in comp_kwp_d.items():
        grp_l = []
        for inds in inds_l:
            MI = pd.DataFrame(index_dict[inds].tolist()).replace('brd-k63750851','mycophenolic acid').set_index([0,1]).index
            msng = MI.difference(DATA.index)
            if msng.shape[0]>0:
                add = MI.swaplevel().intersection(DATA.index)
                MI = MI.difference(msng).union(add)
            grp = DATA.loc[MI]
            grp_l.append(grp)
        if comp_nm.endswith('nonadd_v_add'):            
            grpA,grpB = grp_l
            (lbl1,clr1),(lbl2,clr2) = comp_labels_d[comp_nm]
            clr_data_d[clr1].append((grpA.mean(axis=1),lbl1,pos_ind))
            clr_data_d[clr2].append((grpB.mean(axis=1),lbl2,pos_ind+1))
            rss,rspv = ranksums(grpA.mean(axis=1),grpB.mean(axis=1))
            tts,ttpv = ttest_ind(grpA.mean(axis=1),grpB.mean(axis=1))
            stats_d[(CL,comp_nm,'rs_stat')] = rss
            stats_d[(CL,comp_nm,'rs_pval')] = rspv
            stats_d[(CL,comp_nm,'tt_stat')] = tts
            stats_d[(CL,comp_nm,'tt_pval')] = ttpv
            pos_ind+=2
        else:
            #pos_ind+=1
            lbl_grp_d ={}
            for zz,grp in enumerate(grp_l):
                lbl,clr = comp_labels_d[comp_nm][zz]
                lbl_grp_d[lbl]=grp
                if comp_nm=='growth_tvb_bhv':
                    clr_data_d[clr].append((grp.mean(axis=1),lbl,pos_ind))
                    pos_ind+=1
            for (lbl1,grp1),(lbl2,grp2) in combs(lbl_grp_d.items(),2):
                rss,rspv = ranksums(grpA.mean(axis=1),grpB.mean(axis=1))
                tts,ttpv = ttest_ind(grpA.mean(axis=1),grpB.mean(axis=1))
                str_l=[comp_nm,lbl1,lbl2]
                stats_d[(CL,'_'.join(str_l),'rs_stat')] = rss
                stats_d[(CL,'_'.join(str_l),'rs_pval')] = rspv
                stats_d[(CL,'_'.join(str_l),'tt_stat')] = tts
                stats_d[(CL,'_'.join(str_l),'tt_pval')] = ttpv
            
    clr_data_d = dict(clr_data_d)
    bplot_l = []
    clr_l = []
    for clr,data_l in clr_data_d.items():
        boxdat_l,lbl_l,pos_l = zip(*data_l)
        box = ax.boxplot(boxdat_l,positions=pos_l,labels=lbl_l,widths=0.6,patch_artist=True,notch=False,sym='%s.' % clr,
                         boxprops={'color':clr,'alpha':0.5},whiskerprops={'color':'k'}, capprops={'color':'k'},
                         medianprops={'color':'C3'},flierprops={'alpha':0.5,'markeredgecolor':None})
        bplot_l.append(box)
        clr_l.append(clr)
    ax.fill_betweenx([0,1.5],x1=1.5,x2=7.5,color='C7',alpha=0.2)
    for clr,bplot in zip(clr_l,bplot_l):
        sclr = [box.set_color(clr) for box in bplot['boxes']]
        sal = [box.set_alpha(0.5) for box in bplot['boxes']]
    ax.set_title(CL,size=8)
    ax.set_ylabel('Viability',size=8)
    plt.setp(ax.get_yticklabels(),size=6)
    ax.set_yscale('log')
    ax.set_ylim(4.5e-4,1.5)
plt.setp(ax.get_xticklabels(),rotation=90,size=6)

print('')
## plot the synergy data
axi=0
colkw = 'loewe_12'
cl_sstats_d = {}
for CL,synstat_df in cl_synstat_d.items():
    print(CL)
    pos_ind=0
    sstats_d = {}
    clr_data_d2 = defaultdict(dict)
    high_thr = (synstat_df.loc[:,colkw]/synstat_df.v_12>1)[synstat_df.loc[:,colkw]>BP_THR].mean()
    low_thr = (synstat_df.loc[:,colkw]/synstat_df.v_12>1)[synstat_df.loc[:,colkw]<BP_THR].mean()

    ## need to calculate the expected rate of synergy.
    for comp_nm, inds_l in comp_kwp_d.items():
    #     if comp_nm in ['nonadd_v_add','comb_v_behave','bhv_nonadd_v_add','comb_nonadd_v_add',
    #                    'growth_nonadd_v_add','nonadd_bhv_v_growth','add_bhv_v_growth','nonadd_bhv_v_comb']:
    #         continue
        stats_l = []
        for inds in inds_l:
            MI = pd.DataFrame(index_dict[inds].tolist()).replace('brd-k63750851','mycophenolic acid').set_index([0,1]).index
            msng = MI.difference(synstat_df.index)
            if msng.shape[0]>0:
                add = MI.swaplevel().intersection(synstat_df.index)
                MI = MI.difference(msng).union(add)
            grp = synstat_df.loc[MI]
            obs = (grp.v_12 < grp.loc[:,colkw]) ## rate of synergy
            exp = (grp.loc[:,colkw]<BP_THR).mean() * low_thr + (grp.loc[:,colkw]>BP_THR).mean() * high_thr
            rat = (obs/exp).mean()
            for mm in range(100):
                rac = grp.v_12+grp.v_12_std*np.random.randn(grp.shape[0])
                rloewe_d = {}
                for (kk0,kk1) in grp.index:
                    rloewe_d[(kk0,kk1)] = 1/(10/(myic50_df.loc[kk0,'mu']+myic50_df.loc[kk0,'sig']*np.random.randn())+
                                            10/(myic50_df.loc[kk1,'mu']+myic50_df.loc[kk1,'sig']*np.random.randn())+1)            
                rloewe = pd.Series(rloewe_d)
                rexp = ((rloewe<BP_THR)*low_thr+(rloewe>BP_THR)*high_thr)
                robs =(rac<rloewe).mean()
                obs_l.append(robs)
                exp_l.append(rexp.mean())
                rat_l.append(robs/rexp.mean())
            obs_std=np.std(obs_l)
            exp_std=np.std(exp_l)
            rat_std=np.std(rat_l)
            ## estimate the obs/exp/rat standard deviations
            stats_l.append((obs,exp,rat,obs_std,exp_std,rat_std,grp.shape[0]))
        if comp_nm.endswith('nonadd_v_add'):            
            stats1,stats2 = stats_l
            (lbl1,clr1),(lbl2,clr2) = comp_labels_d[comp_nm]
            obs1,exp1,rat1,obs_std1,exp_std1,rat_std1,nobs1=stats1
            obs2,exp2,rat2,obs_std2,exp_std2,rat_std2,nobs2=stats2
            ## do we want 
            tts,ttpv = ttest_ind_from_stats(rat1,rat_std1,nobs1,rat2,rat_std2,nobs2)
            clr_data_d2[clr1][lbl1] = (rat1,rat_std1/np.sqrt(nobs1),lbl,pos_ind)
            clr_data_d2[clr2][lbl2] = (rat2,rat_std2/np.sqrt(nobs2),lbl,pos_ind+1)
            sstats_d[(CL,comp_nm,'tt_stat')] = tts
            sstats_d[(CL,comp_nm,'tt_pval')] = ttpv
            pos_ind+=2
        else:
            #pos_ind+=1
            lbl_grp_d ={}
            for zz,grp in enumerate(stats_l):
                lbl,clr = comp_labels_d[comp_nm][zz]
                lbl_grp_d[lbl]=grp
                if comp_nm=='growth_tvb_bhv':
                    clr_data_d2[clr][lbl] = (grp[2],grp[5]/np.sqrt(grp[6]),lbl,pos_ind)
                    pos_ind+=1
            for (lbl1,grp1),(lbl2,grp2) in combs(lbl_grp_d.items(),2):
                obs1,exp1,rat1,obs_std1,exp_std1,rat_std1,nobs1=grp1
                obs2,exp2,rat2,obs_std2,exp_std2,rat_std2,nobs2=grp2
                ## do we want 
                tts,ttpv = ttest_ind_from_stats(rat1,rat_std1,nobs1,rat2,rat_std2,nobs2)            
                str_l=[comp_nm,lbl1,lbl2]
                sstats_d[(CL,'_'.join(str_l),'tt_stat')] = tts
                sstats_d[(CL,'_'.join(str_l),'tt_pval')] = ttpv
    clr_data_d2 = dict(clr_data_d2)
    xtls = []
    xinds = []
    ax=ax_l[axi,1]
    axi +=1
    for clr,data in clr_data_d2.items():
        data_df = pd.DataFrame(data)
        ax.errorbar(data_df.iloc[3],data_df.iloc[0],yerr=data_df.iloc[1],fmt=f'{clr}.')
        xinds.extend(data_df.iloc[3].values.tolist())
        for ind,col in data_df.items():
            xtls.append('%s' % (ind))
    srt_xtls,srt_ticks = list(zip(*sorted(zip(xtls,xinds),key=lambda e: e[1])))
    ax.fill_betweenx(y=[0,3],x1=1.5,x2=7.5,color='C7',alpha=0.2)
    ax.set_ylim(0.3,3)
    ax.set_yscale('log',base=2)
    ax.set_title(CL,size=8,family='sans')
    ax.set_ylabel('Synergy ratio',size=8,family='sans')
    ax.axhline(1,ls='--',color='C7')
    cl_sstats_d[CL] = sstats_d
    plt.setp(ax.get_yticklabels(),size=6,family='sans')
ax.set_xticks(srt_ticks)
ax.set_xticklabels(srt_xtls,size=6,rotation=90,family='sans')
fig.savefig(osp.join(OUTPUT_DIR,'exclusive_pairs_combined.svg'))
print('')
cl_sstats_df = pd.DataFrame(cl_sstats_d).stack().droplevel(0).unstack([-1,-2])
cl_sstats_df.to_excel(osp.join(OUTPUT_DIR,'gross_synergy_pvals.xlsx'))
# Out:
# CH-157MN
# GBM43
# IOMM-LEE
# LN-229
#
# CH-157MN
# GBM43
# IOMM-LEE
# LN-229

# %%
## CHANGE TO ONLY USE THE '0.79'/composed variant
## ALSO: combine all cell types into a single comparison

comp_kwp_d = {
    'nonadd_v_add':(('nonadditive', 'comb', 'top'),('additive', 'comb', 'top')),
    #'bhv_nonadd_v_add':(('nonadditive', '0.00', 'top'),('additive', '0.00', 'top')),
    'comb_nonadd_v_add':(('nonadditive', '0.79', 'top'),('additive', '0.79', 'top')),
    #'growth_nonadd_v_add':(('nonadditive', '1.57', 'top'),('additive', '1.57', 'top')),
    'growth_tvb_bhv':(('comb', '0.00', 'top'),('comb', '0.79', 'top'),('comb', '1.57', 'top'),('comb', '1.57', 'bot')),
    'add_bhv':(('additive', '0.00', 'top'),('additive', '0.79', 'top'),('additive', '1.57', 'top')),
    'nonadd_bhv':(('nonadditive', '0.00', 'top'),('nonadditive', '0.79', 'top'),('nonadditive', '1.57', 'top'))
}

comp_labels_d = {
    'nonadd_v_add':(('Nonadditive','C7'),('Additive', 'C7')),
    #'bhv_nonadd_v_add':(('Nonadditive','C0'),('Additive', 'C0')),
    'comb_nonadd_v_add':(('Nonadditive', 'C1'),('Additive', 'C1')),
    #'growth_nonadd_v_add':(('Nonadditive', 'C2'),('Additive', 'C2')),
    'growth_tvb_bhv':(('Behavior','C0'),('Combined', 'C1'),('Growth', 'C2'),('Non-growth','C3')),
    'nonadd_bhv':(('Behavior','C0'),('Combined', 'C1'),('Growth', 'C2')),
    'add_bhv':(('Behavior','C0'),('Combined', 'C1'),('Growth', 'C2')),
}

plt.rcParams['svg.fonttype']='none'
stats_d = {}
fig,ax_l = plt.subplots(4,2,dpi=180,figsize=(6,6),sharex=True)
axi=0
for CL,drg_data_d in cl_drg_data_d.items():
    ## compare the drug viability data
    print(CL)
    ax=ax_l[axi,0]
    axi +=1
    DATA = pd.DataFrame(drg_data_d).T
    DATA.index = pd.MultiIndex.from_tuples([k if isinstance(k,tuple) else (k,'dmso') for k in DATA.index])
    pos_ind = 0
    clr_data_d = defaultdict(list)
    for comp_nm, inds_l in comp_kwp_d.items():
        grp_l = []
        for inds in inds_l:
            MI = pd.DataFrame(index_dict[inds].tolist()).replace('brd-k63750851','mycophenolic acid').set_index([0,1]).index
            msng = MI.difference(DATA.index)
            if msng.shape[0]>0:
                add = MI.swaplevel().intersection(DATA.index)
                MI = MI.difference(msng).union(add)
            grp = DATA.loc[MI]
            grp_l.append(grp)
        if comp_nm.endswith('nonadd_v_add'):            
            grpA,grpB = grp_l
            (lbl1,clr1),(lbl2,clr2) = comp_labels_d[comp_nm]
            clr_data_d[clr1].append((grpA.mean(axis=1),lbl1,pos_ind))
            clr_data_d[clr2].append((grpB.mean(axis=1),lbl2,pos_ind+1))
            rss,rspv = ranksums(grpA.mean(axis=1),grpB.mean(axis=1))
            tts,ttpv = ttest_ind(grpA.mean(axis=1),grpB.mean(axis=1))
            stats_d[(CL,comp_nm,'rs_stat')] = rss
            stats_d[(CL,comp_nm,'rs_pval')] = rspv
            stats_d[(CL,comp_nm,'tt_stat')] = tts
            stats_d[(CL,comp_nm,'tt_pval')] = ttpv
            pos_ind+=2
        else:
            #pos_ind+=1
            lbl_grp_d ={}
            for zz,grp in enumerate(grp_l):
                lbl,clr = comp_labels_d[comp_nm][zz]
                lbl_grp_d[lbl]=grp
                if comp_nm=='growth_tvb_bhv':
                    clr_data_d[clr].append((grp.mean(axis=1),lbl,pos_ind))
                    pos_ind+=1
            for (lbl1,grp1),(lbl2,grp2) in combs(lbl_grp_d.items(),2):
                rss,rspv = ranksums(grpA.mean(axis=1),grpB.mean(axis=1))
                tts,ttpv = ttest_ind(grpA.mean(axis=1),grpB.mean(axis=1))
                str_l=[comp_nm,lbl1,lbl2]
                stats_d[(CL,'_'.join(str_l),'rs_stat')] = rss
                stats_d[(CL,'_'.join(str_l),'rs_pval')] = rspv
                stats_d[(CL,'_'.join(str_l),'tt_stat')] = tts
                stats_d[(CL,'_'.join(str_l),'tt_pval')] = ttpv
            
    clr_data_d = dict(clr_data_d)
    bplot_l = []
    clr_l = []
    for clr,data_l in clr_data_d.items():
        boxdat_l,lbl_l,pos_l = zip(*data_l)
        box = ax.boxplot(boxdat_l,positions=pos_l,labels=lbl_l,widths=0.6,patch_artist=True,notch=False,sym='%s.' % clr,
                         boxprops={'color':clr,'alpha':0.5},whiskerprops={'color':'k'}, capprops={'color':'k'},
                         medianprops={'color':'C3'},flierprops={'alpha':0.5,'markeredgecolor':None})
        bplot_l.append(box)
        clr_l.append(clr)
    ax.fill_betweenx([0,1.5],x1=1.5,x2=7.5,color='C7',alpha=0.2)
    for clr,bplot in zip(clr_l,bplot_l):
        sclr = [box.set_color(clr) for box in bplot['boxes']]
        sal = [box.set_alpha(0.5) for box in bplot['boxes']]
    ax.set_title(CL,size=8)
    ax.set_ylabel('Viability',size=8)
    plt.setp(ax.get_yticklabels(),size=6)
    ax.set_yscale('log')
    ax.set_ylim(4.5e-4,1.5)
plt.setp(ax.get_xticklabels(),rotation=90,size=6)

print('')
## plot the synergy data
axi=0
colkw = 'loewe_12'
cl_sstats_d = {}
for CL,synstat_df in cl_synstat_d.items():
    print(CL)
    pos_ind=0
    sstats_d = {}
    clr_data_d = defaultdict(dict)
    high_thr = (synstat_df.loc[:,colkw]/synstat_df.v_12>1)[synstat_df.loc[:,colkw]>BP_THR].mean()
    low_thr = (synstat_df.loc[:,colkw]/synstat_df.v_12>1)[synstat_df.loc[:,colkw]<BP_THR].mean()

    ## need to calculate the expected rate of synergy.
    for comp_nm, inds_l in comp_kwp_d.items():
    #     if comp_nm in ['nonadd_v_add','comb_v_behave','bhv_nonadd_v_add','comb_nonadd_v_add',
    #                    'growth_nonadd_v_add','nonadd_bhv_v_growth','add_bhv_v_growth','nonadd_bhv_v_comb']:
    #         continue
        stats_l = []
        for inds in inds_l:
            MI = pd.DataFrame(index_dict[inds].tolist()).replace('brd-k63750851','mycophenolic acid').set_index([0,1]).index
            msng = MI.difference(synstat_df.index)
            if msng.shape[0]>0:
                add = MI.swaplevel().intersection(synstat_df.index)
                MI = MI.difference(msng).union(add)
            grp = synstat_df.loc[MI]
            obs = (grp.v_12 < grp.loc[:,colkw]) ## rate of synergy
            exp = (grp.loc[:,colkw]<BP_THR).mean() * low_thr + (grp.loc[:,colkw]>BP_THR).mean() * high_thr
            rat = (obs/exp).mean()
            for mm in range(100):
                rac = grp.v_12+grp.v_12_std*np.random.randn(grp.shape[0])
                rloewe_d = {}
                for (kk0,kk1) in grp.index:
                    rloewe_d[(kk0,kk1)] = 1/(10/(myic50_df.loc[kk0,'mu']+myic50_df.loc[kk0,'sig']*np.random.randn())+
                                            10/(myic50_df.loc[kk1,'mu']+myic50_df.loc[kk1,'sig']*np.random.randn())+1)            
                rloewe = pd.Series(rloewe_d)
                rexp = ((rloewe<BP_THR)*low_thr+(rloewe>BP_THR)*high_thr)
                robs =(rac<rloewe).mean()
                obs_l.append(robs)
                exp_l.append(rexp.mean())
                rat_l.append(robs/rexp.mean())
            obs_std=np.std(obs_l)
            exp_std=np.std(exp_l)
            rat_std=np.std(rat_l)
            ## estimate the obs/exp/rat standard deviations
            stats_l.append((obs,exp,rat,obs_std,exp_std,rat_std,grp.shape[0]))
        if comp_nm.endswith('nonadd_v_add'):            
            stats1,stats2 = stats_l
            (lbl1,clr1),(lbl2,clr2) = comp_labels_d[comp_nm]
            obs1,exp1,rat1,obs_std1,exp_std1,rat_std1,nobs1=stats1
            obs2,exp2,rat2,obs_std2,exp_std2,rat_std2,nobs2=stats2
            ## do we want 
            tts,ttpv = ttest_ind_from_stats(rat1,rat_std1,nobs1,rat2,rat_std2,nobs2)
            clr_data_d[clr1][lbl1] = (rat1,rat_std1/np.sqrt(nobs1),lbl,pos_ind)
            clr_data_d[clr2][lbl2] = (rat2,rat_std2/np.sqrt(nobs2),lbl,pos_ind+1)
            sstats_d[(CL,comp_nm,'tt_stat')] = tts
            sstats_d[(CL,comp_nm,'tt_pval')] = ttpv
            pos_ind+=2
        else:
            #pos_ind+=1
            lbl_grp_d ={}
            for zz,grp in enumerate(stats_l):
                lbl,clr = comp_labels_d[comp_nm][zz]
                lbl_grp_d[lbl]=grp
                if comp_nm=='growth_tvb_bhv':
                    clr_data_d[clr][lbl] = (grp[2],grp[5]/np.sqrt(grp[6]),lbl,pos_ind)
                    pos_ind+=1
            for (lbl1,grp1),(lbl2,grp2) in combs(lbl_grp_d.items(),2):
                obs1,exp1,rat1,obs_std1,exp_std1,rat_std1,nobs1=grp1
                obs2,exp2,rat2,obs_std2,exp_std2,rat_std2,nobs2=grp2
                ## do we want 
                tts,ttpv = ttest_ind_from_stats(rat1,rat_std1,nobs1,rat2,rat_std2,nobs2)            
                str_l=[comp_nm,lbl1,lbl2]
                sstats_d[(CL,'_'.join(str_l),'tt_stat')] = tts
                sstats_d[(CL,'_'.join(str_l),'tt_pval')] = ttpv
    clr_data_d = dict(clr_data_d)
    xtls = []
    xinds = []
    ax=ax_l[axi,1]
    axi +=1
    for clr,data in clr_data_d.items():
        data_df = pd.DataFrame(data)
        ax.errorbar(data_df.iloc[3],data_df.iloc[0],yerr=data_df.iloc[1],fmt='%s.' % clr)
        xinds.extend(data_df.iloc[3].values.tolist())
        for ind,col in data_df.items():
            xtls.append('%s' % (ind))
    srt_xtls,srt_ticks = list(zip(*sorted(zip(xtls,xinds),key=lambda e: e[1])))
    ax.fill_betweenx(y=[0,3],x1=1.5,x2=7.5,color='C7',alpha=0.2)
    ax.set_ylim(0.3,3)
    ax.set_yscale('log',base=2)
    ax.set_title(CL,size=8,family='sans')
    ax.set_ylabel('Synergy ratio',size=8,family='sans')
    ax.axhline(1,ls='--',color='C7')
    cl_sstats_d[CL] = sstats_d
    plt.setp(ax.get_yticklabels(),size=6,family='sans')
ax.set_xticks(srt_ticks)
ax.set_xticklabels(srt_xtls,size=6,rotation=90,family='sans')
fig.savefig(osp.join(OUTPUT_DIR,'exclusive_pairs_combined.svg'))
print('')
cl_sstats_df = pd.DataFrame(cl_sstats_d).stack().droplevel(0).unstack([-1,-2])
cl_sstats_df.to_excel(osp.join(OUTPUT_DIR,'gross_synergy_pvals.xlsx'))
# Out:
# CH-157MN
# GBM43
# IOMM-LEE
# LN-229
#
# CH-157MN
# GBM43
# IOMM-LEE
# LN-229

# %% [markdown]
# ### Fig. S4 (dose-response curves)

# %%
for CL in ['IOMM-Lee','CH157']:
    obs1210 = pd.read_excel(osp.join(INPUT_DIR,'2021-12-10-CTG-CH157-Lee.xlsx'),
                            engine='openpyxl',sheet_name='%s Torin Calc' % CL,
                            usecols='AA:AL',index_col=0,header=1,nrows=11)
    #obs1210= obs1210.iloc[:,1:12]
    obs1210.columns = ['1uM','0.5uM','0.25uM','0.125uM','0.063uM','0.031uM','0.016uM','0.008uM','0.004uM','0.002uM','0uM']
    obs1210.index = [elt.split(' ')[0] for elt in obs1210.index]
    obs1210.index.name='Digitoxin'
    obs1210.columns.name='Torin 2'
    pred1210 = pd.read_excel(osp.join(INPUT_DIR,'2021-12-10-CTG-CH157-Lee.xlsx'),
                             engine='openpyxl',sheet_name='%s Torin Calc' % CL,
                             usecols='AA:AL',index_col=0,header=14,nrows=11)
    #pred1210= pred1210.iloc[:,1:12]
    pred1210.columns = ['1uM','0.5uM','0.25uM','0.125uM','0.063uM','0.031uM','0.016uM','0.008uM','0.004uM','0.002uM','0uM']
    pred1210.index = [elt.split(' ')[0] for elt in pred1210.index]
    pred1210.index.name='Digitoxin'
    pred1210.columns.name='Torin 2'

    figsize_in = (7.5,1.83)

    lblpad = 0.05
    cbpad = 0.005
    cblbl = 0.075
    cbwidth = 0.015
    pwidth = 1/3 - (lblpad + cbpad + cblbl + cbwidth)

    toppad = .025
    pheight = .75 
    botpad = .225

    fig = plt.figure(figsize=figsize_in,dpi=180)
    ax1 = fig.add_axes([lblpad,botpad,pwidth,pheight])
    ax2 = fig.add_axes([lblpad+(lblpad+pwidth+cbpad+cbwidth+cblbl),botpad,pwidth,pheight])
    ax3 = fig.add_axes([lblpad+2*(lblpad+pwidth+cbpad+cbwidth+cblbl),botpad,pwidth,pheight])

    cbax1 = fig.add_axes([lblpad+pwidth+cbpad,botpad,cbwidth,pheight])
    cbax2 = fig.add_axes([lblpad+pwidth+cbpad+(lblpad+pwidth+cbpad+cbwidth+cblbl),botpad,cbwidth,pheight])
    cbax3 = fig.add_axes([lblpad+pwidth+cbpad+2*(lblpad+pwidth+cbpad+cbwidth+cblbl),botpad,cbwidth,pheight])
    vcm = plt.get_cmap('viridis')

    LN = LogNorm(vmin=1e-2, vmax=10,clip=True)
    Ndose = obs1210.shape[0]
    obj_l = []
    lvl_l = []
    lw_l = []
    ls_l = []
    clr_l = []
    alpha=0.1
    for ii in range(Ndose-1,-1,-1):
        numcols = [float(nm[:-2])+1e-3 for nm in obs1210.columns][::-1]
        CC = float(obs1210.index[ii][:-2])+1e-4
        obj =ax1.plot(numcols,1-obs1210.iloc[ii,::-1],color=vcm(LN(CC)),ls='--',marker='o',alpha=0.5,label='%.2e' % CC)
        xdat,ydat = obj[0].get_data()
        lw_l.append(obj[0].get_lw())
        ls_l.append(obj[0].get_ls())
        clr_l.append(obj[0].get_color())
        obj_l.append([np.c_[xdat[:3],ydat[:3]].tolist()])
        lvl_l.append(CC)
    CS = mpl.contour.ContourSet(ax1,lvl_l,obj_l,linewidths=lw_l,linestyles=ls_l,colors=clr_l,norm=LN)
    cb1 = fig.colorbar(CS,cax=cbax1,format=mpl.ticker.LogFormatter(2,labelOnlyBase=False))
    ax1.set_xscale('log')
    plt.setp(ax1.get_xticklabels(),size=6)
    plt.setp(ax1.get_yticklabels(),size=6)
    ax1.set_ylabel('Viability',size=6)
    ax1.set_xlabel(obs1210.columns.name + r' ($\mu$M)',size=6)
    cb1.set_label(obs1210.index.name + r' ($\mu$M)',size=6)
    plt.setp(cb1.ax.yaxis.get_ticklabels(),size=6)

    LN2 = LogNorm(vmin=1e-3, vmax=1,clip=True)
    Ndose = obs1210.shape[1]
    obj_l = []
    lvl_l = []
    lw_l = []
    ls_l = []
    clr_l = []
    alpha=0.1
    for ii in range(Ndose-1,-1,-1):
        numcols = [float(nm[:-2])+1e-2 for nm in obs1210.index][::-1]
        CC = float(obs1210.columns[ii][:-2])+1e-4
        obj =ax2.plot(numcols,1-obs1210.iloc[::-1,ii],color=vcm(LN2(CC)),ls='--',marker='o',alpha=0.5,label='%.2e' % CC)
        xdat,ydat = obj[0].get_data()
        lw_l.append(obj[0].get_lw())
        ls_l.append(obj[0].get_ls())
        clr_l.append(obj[0].get_color())
        obj_l.append([np.c_[xdat[:3],ydat[:3]].tolist()])
        lvl_l.append(CC)
    CS = mpl.contour.ContourSet(ax2,lvl_l,obj_l,linewidths=lw_l,linestyles=ls_l,colors=clr_l,norm=LN)
    cb2 = fig.colorbar(CS,cax=cbax2,format=mpl.ticker.LogFormatter(2,labelOnlyBase=False))
    ax2.set_xscale('log')
    ax2.set_ylabel('Viability',size=6)
    plt.setp(ax2.get_xticklabels(),size=6)
    plt.setp(ax2.get_yticklabels(),size=6)
    ax2.set_xlabel(obs1210.index.name + r' ($\mu$M)',size=6)
    cb2.set_label(obs1210.columns.name + r' ($\mu$M)',size=6)
    plt.setp(cb2.ax.yaxis.get_ticklabels(),size=6)

    
    mycmap = plt.get_cmap('bwr')
    img = ax3.imshow((obs1210-pred1210).iloc[4:10,4:10].iloc[::-1,::-1]*100,origin='lower',cmap=mycmap,norm=CenteredNorm())
    ax3.set_xticks(np.arange(6))
    ax3.set_yticks(np.arange(6))
    ax3.set_xticklabels([ '%.3f' % float(col[:-2]) for col in  obs1210.columns[4:10]][::-1],size=6,horizontalalignment='right',rotation=30)
    ax3.set_yticklabels([ '%.2f' % float(col[:-2]) for col in  obs1210.index[4:10]][::-1],size=6)
    ax3.set_xlabel(r'Torin 2 ($\mu$M)',size=6)
    ax3.set_ylabel(r'Digitoxin ($\mu$M)',size=6)
    cb3 = fig.colorbar(img,cax=cbax3)
    cb3.set_label('Bliss synergy (%)',size=6)
    plt.setp(cb3.ax.yaxis.get_ticklabels(),size=6)
    fig.savefig(osp.join(OUTPUT_DIR,f'figS4_dose_response_{CL}_digitoxin_torin2.svg'))

# %% [markdown]
# ### Fig. 4

# %% [markdown]
# #### Fig. 4A

# %%
## total number of single drugs assayed
len((set(test_grps.drug1_name.unique())|set(test_grps.drug2_name.unique()))-set([np.nan]))
# Out:
# 157

# %%
total_single = set([np.nan])
add2unselected = ['Behavior additive (blue)', 'Behavior average (blue)', 'Behavior nonadditive (blue)','Growth additive (green)',
 'Growth average (green)', 'Growth nonadditive (green)','Unselected']
add2topspec = ['Additive average (gray)','Nonadditive average (gray)','Combined additive (orange)', 'Combined average (orange)', 'Combined nonadditive (orange)','Non-growth average (red)']

stacked_single_d = {}
for kw in ['Top (consensus)','Top (specific)','Non-cancer','Anti-selected','Unselected']:
    if kw=='Top (consensus)':
        selection = test_grps[test_grps.group=='Top selected (brown)']
    elif kw=='Top (specific)':
        selection = test_grps[test_grps.group.isin(add2topspec)]
    elif kw=='Non-cancer' or kw == 'Anti-selected':
        selection = test_grps[test_grps.group==kw]
    elif kw=='Unselected':
        selection = test_grps[test_grps.group.isin(add2unselected)]
    selsng1 = selection.drug1_name.unique()
    selsng2 = selection.drug2_name.unique()
    singles_set = (set(selsng1)|set(selsng2))-total_single
    total_single |= singles_set
    stacked_single_d[kw]=len(singles_set)
low_dosage_sel = test_grps[test_grps.group=='Low-dosage']
ldsel1 = low_dosage_sel.drug1_name.unique()
ldsel2 = low_dosage_sel.drug2_name.unique()
stacked_single_d['Low-dosage'] = len((set(ldsel1)|set(ldsel2)) - set([np.nan]))

## the "selected specific" should correspond to the nonadditive vs. additive drugs
## the drugs included to investigate individual selected variants of the methods should be organized into a separate group or "unselected"
stacked_pairs_d = {} ## container for the drug counts
LBL_D = {'Unselected':'Unselected',
         'Low-dosage':'Low-dosage',
         'Anti-selected':'Anti-selected',
         'Non-cancer':'Non-cancer',
         'Top selected (brown)':'Top (consensus)',
         'Top selected (purple)':'NA',
         'Other':'NA2'}
OTHER_GRPS = {'Additive average (gray)', 'Behavior additive (blue)', 'Behavior average (blue)', 'Behavior nonadditive (blue)',
 'Combined additive (orange)', 'Combined average (orange)', 'Combined nonadditive (orange)', 'Growth additive (green)',
 'Growth average (green)', 'Growth nonadditive (green)', 'Non-growth average (red)', 'Nonadditive average (gray)'}
SEL_GRPS = ['Unselected (yellow)','Low dosage (cyan)','Anti-selected (pink)','Non-cancer (brown)','Top selected (brown)','Top selected (purple)']
for grpnm,LBL in LBL_D.items():
    if grpnm in ['Top selected (purple)']:
        continue
    else:
        if grpnm in ['Low-dosage','Anti-selected','Non-cancer','Top selected (brown)']:
            sel = test_grps[test_grps.group==grpnm] 
            LBL = LBL_D[grpnm]
        elif grpnm =='Unselected':
            LBL = LBL_D[grpnm]
            sel = test_grps[test_grps.group.isin(add2unselected)]
        else:
            LBL = 'Top (specific)'
            sel = test_grps[test_grps.group.isin(add2topspec)]
        sel_sng = sel[sel.drug2_name.isna()]
        sel_pair = sel[~sel.drug2_name.isna()]
        ## save as part of drug pairs
        stacked_pairs_d[LBL] = sel_pair.shape[0] 
    
stacked_pairs_ser = pd.Series(dict(stacked_pairs_d))
stacked_single_ser = pd.Series(dict(stacked_single_d))
stacked_data_df = pd.concat({'Drug pairs':stacked_pairs_ser,'Single drugs':stacked_single_ser},axis=1)

# %%
# purple, yellow, red, light blue, pink
clr_l = ['C1','w','C2','#EDB120','#4DBEEE','#E377c2']
grplbls = ['Top (consensus)','Top (specific)','Non-cancer','Anti-selected','Unselected','Low-dosage']
fig,ax = plt.subplots(1,1,dpi=180,frameon=False,figsize=(2,3))
for ii,col in enumerate(['Drug pairs','Single drugs']):
    ll = 0 
    for clr,lbl in zip(clr_l,grplbls):
        hh = stacked_data_df.loc[lbl,col]
        ax.bar([ii],height=[hh],bottom=[ll],label='%s (%d)'%(lbl,hh),color=clr,alpha=0.8)
        ll+=hh
ax.set_xlim(-0.5,1.5)
ax.legend(frameon=False,prop={'size':6},ncol=2)
ax.set_xticks([0,1])
ax.set_xticklabels(['Drug pairs','Single drugs'],size=6, horizontalalignment='center')
ax.set_ylabel('Number',size=8)
plt.setp(ax.get_yticklabels(),size=6)
fig.savefig(f'{OUTPUT_DIR}/fig4a_drug_selection_counts.svg')

# %%
# Out:
# ['Behavior additive (blue)',
#  'Behavior average (blue)',
#  'Behavior nonadditive (blue)',
#  'Growth additive (green)',
#  'Growth average (green)',
#  'Growth nonadditive (green)',
#  'Unselected']

# %% [markdown]
# #### Fig. 4BC

# %%
top_sel_consensus = list(set(index_dict[('all','all','top')])-set(shared_l))
top_sel_specific = set([])
for k,v in index_dict.items():
    if k == ('all', 'all', 'top'):
        continue
    else:
        top_sel_specific |= (set(v) - set(shared_l))
        
top_sel_specific = list(top_sel_specific)
top_sel_specific2 = []
for (x,y) in top_sel_specific:
    if x=='brd-k63750851':
        xp = 'mycophenolic acid'
    elif x=='hydrocortisone':
        xp = 'cortisol'
    else:
        xp = x
    if y=='tretinoin':
        yp = 'retinoic acid'
    else:
        yp = y
    top_sel_specific2.append((xp,yp))
        ## cycle through and replace...
top_sel_specific=top_sel_specific2
grplbls = ['Top (consensus)','Non-cancer','Anti-selected',
           'Unselected','Top (model-specific)','Low-dosage']
grplbl_d = {'top':'Top (consensus)', 'noncanc':'Non-cancer', 
            'anti':'Anti-selected', 'random':'Unselected', 'top_spec':'Top (model-specific)'}
drggrps = [top_sel_consensus,noncanc_l,antisel_pairs,
           nonsel_pairs,top_sel_specific,ld_pairs]

axi=0
clr_l = ['C1','C2','#EDB120','#4DBEEE','#E377c2']
## make the boxplots
fig,ax_l = plt.subplots(2,4,dpi=180,figsize=(4,3),sharex='col',sharey='row')
ovrstats_d = {}
for CL,drg_data_d in cl_drg_data_d.items():
    print(CL)
    ax=ax_l[0,axi]
    axi +=1
    DATA = pd.DataFrame(drg_data_d).T
    DATA.index = pd.MultiIndex.from_tuples([k if isinstance(k,tuple) else (k,'dmso') for k in DATA.index])
    pos=0    
    for clr,lbl,grp in zip(clr_l,grplbls,drggrps):
        if lbl in ['Low-dosage','Top (model-specific)']:
            continue
        elif lbl=='Unselected':
            add2unselected2 =set(add2unselected)-set(['Unselected'])
            gd1 = DATA.loc[[tuple(elt) for elt in test_grps[test_grps.group.isin(add2unselected2)].loc[:,['drug1_name','drug2_name']].values if isinstance(elt[1],str)]].mean(axis=1)
            gd2 = DATA.loc[grp].mean(axis=1)
            grpdat = pd.concat([gd1,gd2],axis=0)
        else:
            grpdat = DATA.loc[grp].mean(axis=1)


        grpdat = DATA.loc[grp].mean(axis=1)
        boxes = ax.boxplot([grpdat],labels=[lbl],positions=[pos],patch_artist=True,notch=False,
                           boxprops={'color':clr,'alpha':1},whiskerprops={'color':'k'},
                           widths=0.6,capprops={'color':'k'},
                           medianprops={'color':'C3'},flierprops={'marker':'.','markerfacecolor':clr,'alpha':0.5,'markeredgecolor':'none'})

        sclr = boxes['boxes'][0].set_color(clr)
        sal = boxes['boxes'][0].set_alpha(0.8)
        pos+=1
    for (lbl1,grp1),(lbl2,grp2) in combs(dict(zip(grplbls,drggrps)).items(),2):
        if lbl1 == 'Low-dosage' or lbl2=='Low-dosage':
            continue
        if lbl1 == 'Unselected':
            add2unselected2 =set(add2unselected)-set(['Unselected'])
            gdA = DATA.loc[[tuple(elt) for elt in test_grps[test_grps.group.isin(add2unselected2)].loc[:,['drug1_name','drug2_name']].values]].mean(axis=1)
            gdB = DATA.loc[grp1].mean(axis=1)
            DATA1 = pd.concat([gdA,gdB],axis=0)
        else:
            DATA1 = DATA.loc[grp1].mean(axis=1)
        if lbl2 == 'Unselected':
            add2unselected2 =set(add2unselected)-set(['Unselected'])
            gdA = DATA.loc[[tuple(elt) for elt in test_grps[test_grps.group.isin(add2unselected2)].loc[:,['drug1_name','drug2_name']].values]].mean(axis=1)
            gdB = DATA.loc[grp2].mean(axis=1)
            DATA2 = pd.concat([gdA,gdB],axis=0)
        else:
            DATA2 = DATA.loc[grp2].mean(axis=1)

        rss,rspv = ranksums(DATA1,DATA2)
        tts,ttpv = ttest_ind(DATA1,DATA2)
        str_l=[lbl1,lbl2]
        ovrstats_d[(CL,'_'.join(str_l),'rs_stat')] = rss
        ovrstats_d[(CL,'_'.join(str_l),'rs_pval')] = rspv
        ovrstats_d[(CL,'_'.join(str_l),'tt_stat')] = tts
        ovrstats_d[(CL,'_'.join(str_l),'tt_pval')] = ttpv
        
    ax.set_title(CL,size=8)
    ax.set_yscale('log')
ax.set_yticks(np.logspace(-3,0,4))
ax_l[0,0].set_ylabel('Viability',size=8)
plt.setp(ax_l[0,0].get_yticklabels(),size=6)

## make the synergy ratio Fig. S
dumdum = plt.setp(ax.get_xticklabels(),size=6,rotation=30,horizontalalignment='right')
axi = 0
for CL,rat_data in gross_synergy_stats.groupby(level=0):
    ax = ax_l[1,axi]
    #clr=clr_l[axi]
    axi+=1
    key_ovr = ['top', 'noncanc', 'anti', 'random']#list(set(rat_data.get_level_values(1)) & set(grplbl_d.keys()))
    srat_data = rat_data.droplevel(0).loc[key_ovr,'ratio':'ratio_std']
    xvals = np.arange(srat_data.shape[0])
    for ii in range(srat_data.shape[0]):
        ax.errorbar(xvals[ii],srat_data.iloc[ii,0],yerr=srat_data.iloc[ii,1],fmt='.',
                   ecolor=clr_l[ii],markerfacecolor=clr_l[ii],markeredgecolor=clr_l[ii])
    ax.axhline(1,ls='--',color='C7')
    ax.set_xticks(xvals)
    ax.set_xticklabels([grplbl_d[kovr] for kovr in key_ovr],size=6,rotation=30)
    dumdum = plt.setp(ax.get_xticklabels(),size=6,rotation=30,horizontalalignment='right')
    #plt.setp(ax.get_yticklabels(),size=6)
    #ax.set_title(CL,size=8)
ax_l[1,0].set_ylabel('Synergy ratio',size=8)
ax_l[1,0].set_ylim(0,1.3)
plt.setp(ax_l[1,0].get_yticklabels(),size=6)

#ax.set_yscale('log',base=2)

fig.savefig(osp.join(OUTPUT_DIR,'fig4bc_gross_comparisons.svg'))
## statistical comparisons of the boxplots
pd.Series(ovrstats_d).unstack([-2,-1]).to_excel(osp.join(OUTPUT_DIR,'fig4_viability_stats.xlsx'))
# Out:
# CH-157MN
# GBM43
# IOMM-LEE
# LN-229
